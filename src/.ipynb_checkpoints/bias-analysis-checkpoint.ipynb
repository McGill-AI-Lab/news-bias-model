# %% [markdown]
# What we need to do:
# 1) Go through each newspaper and create a newspaper corpora, display the length of each corpora
# 2) Find either a) wikipedia dataset and train word2vec on it to compare non-context related words like "bad",
# "victim", "good", "attacker" to representation of each side of the conflict in the newspaper corpora, b) find a
# pretrained word2vec to do the same
# 3) Find a way to classify each article as pro-israel or pro-palestine

# %%
import json

# Open and read the JSON file
with open('data/news-data-extracted.json', 'r') as file:
    data = json.load(file)

# Print the data
first_article_data = data["cnn.com"][0] #cnn is the key to a value which is a list of dictionaries, we get the first dictionary (article) of that list of dictionary
first_article = first_article_data["text"]
print(first_article_data)
# Out:
# {'url': 'https://www.cnn.com/2020/01/23/opinions/auschwitz-anniversary-anti-semitism-fears-linger-andelman/index.html', 'title': 'World leaders in Jerusalem show battle against anti-Semitism not yet a victory (opinion)', 'authors': ['David A. Andelman'], 'date': '2020-01-23 00:00:00', 'text': 'Editors Note: David A. Andelman, Executive Director of The RedLines Project, is a contributor to CNN where his columns won the Deadline Club Award for Best Opinion Writing. Author of A Shattered Peace: Versailles 1919 and the Price We Pay Today, and the forthcoming A Red Line in the Sand: Diplomacy, Strategy and a History of Wars That Almost Happened, he was formerly a foreign correspondent for The New York Times and CBS News in Europe and Asia. Follow him on Twitter @DavidAndelman. The views expressed in this commentary are his own. View more opinion on CNN.CNN The world converged on Jerusalem this week to observe the 75th anniversary of the liberation of the Auschwitz death camp  and with a collective determination to battle anti-Semitism in its many forms. At the same time, the gathering exposed a number of old and festering political wounds, which threatened to weaken the impact of it.Some 40 heads of state or government from Russian President Vladimir Putin to French President Emmanuel Macron traveled to Israels Yad Vashem Holocaust memorial to pay homage to those who died and to pledge never again. The actual anniversary of the liberation of Auschwitz, where at least 1.1 million were slaughtered in the Nazi death camp, will be marked on Monday in Poland.In Israel, though, there were noticeable absentees and a succession of contretemps.Poland and Lithuania, for example, have accused Putin of reviving Stalinist-era tropes when hes claimed the Soviet Union saved the world from Nazism and framed the Polish people as participating in the Holocaust. So, when Putin was given a speaking role at Yad Vashem, Presidents Andrzej Duda of Poland and Lithuanias Gitanas Nauseda declined to attend.Meanwhile, French President Emmanuel Macron got into a minor shouting match with Israeli police, who sought to enter the medieval Church of Saint Anne in Jerusalem  French territory since the 19th century  ahead of the French leader. (Notably, a nearly identical incident happened with the late French President Jacques Chirac in 1996).Later, however, during a group photo of the world leaders at the home of Israeli President Reuven Rivlin, Macron was strategically pictured front and center between hosts Rivlin and Prime Minister Benjamin Netanyahu.In a fight for his own political life, under indictment for corruption and facing new elections in March, Netanyahu has been making the most of this weeks events. He even leaned into his role as statesman, strolling for television cameras with Putin and then taking him on a visit to the mother of Naama Issachar, an Israeli-American woman imprisoned in Russia.This awkward moment as leader of a country keeping a womans child in prison was just one of the issues facing Putin at the ceremonies. He must decide whether to free Issachar, who is serving seven and a half years in prison after marijuana was found in her luggage while she transited a Moscow airport. (Issachar maintains the drugs were planted on her, and she was forced into signing a false confession.)Israeli media suggested Putin was demanding a number of gestures from Israel before Putin agrees to release her, a decision which seems increasingly likely after the high-octane campaign on her behalf.And, in Paris, Macron is facing demands, reiterated by Netanyahu during their meeting, to deal with the murder of Sarah Halimi, a 65-year-old French Jew who was thrown from her Paris apartment window in 2017. A French court ruled that the killer was not criminally responsible. Despite the court ruling, many protesters in France believe the killing of Halimi to be an anti-Semitic act.Meanwhile, Macron  as well as leaders across the globe  have a broader range of iss ...

# %%
first_article[0]
# Out:
# 'E'

# %%
from gensim.utils import tokenize
from nltk.tokenize import sent_tokenize
from nltk.corpus import stopwords

def tokenize_article(article):
    tokenized_article = []
    sentences  = sent_tokenize(article, language="english") # divide article into sentences
    
    for sentence in sentences:
        tokenized_sentence = tokenize(sentence) # divide sentences into words
        tokenized_article.append(tokenized_sentence) 
    return tokenized_article


stop_words = set(stopwords.words("english"))

def remove_stopwords(tokenized_article):
    # Iterate over the index and content of each sentence
    for i in range(len(tokenized_article)):
        # Create a new list for the filtered sentence
        filtered_sentence = []
        for word in tokenized_article[i]:
            if word not in stop_words:
                filtered_sentence.append(word)
        # Replace the original sentence with the filtered sentence
        tokenized_article[i] = filtered_sentence
    return tokenized_article

def preprocess_article(article):
    return remove_stopwords(tokenize_article(article))

# %%
print(preprocess_article(first_article))
# Out:
# [['Editors', 'Note', 'David', 'A', 'Andelman', 'Executive', 'Director', 'The', 'RedLines', 'Project', 'contributor', 'CNN', 'columns', 'Deadline', 'Club', 'Award', 'Best', 'Opinion', 'Writing'], ['Author', 'A', 'Shattered', 'Peace', 'Versailles', 'Price', 'We', 'Pay', 'Today', 'forthcoming', 'A', 'Red', 'Line', 'Sand', 'Diplomacy', 'Strategy', 'History', 'Wars', 'That', 'Almost', 'Happened', 'formerly', 'foreign', 'correspondent', 'The', 'New', 'York', 'Times', 'CBS', 'News', 'Europe', 'Asia'], ['Follow', 'Twitter', 'DavidAndelman'], ['The', 'views', 'expressed', 'commentary'], ['View', 'opinion', 'CNN', 'CNN', 'The', 'world', 'converged', 'Jerusalem', 'week', 'observe', 'th', 'anniversary', 'liberation', 'Auschwitz', 'death', 'camp', 'collective', 'determination', 'battle', 'anti', 'Semitism', 'many', 'forms'], ['At', 'time', 'gathering', 'exposed', 'number', 'old', 'festering', 'political', 'wounds', 'threatened', 'weaken', 'impact', 'Some', 'heads', 'state', 'government', 'Russian', 'President', 'Vladimir', 'Putin', 'French', 'President', 'Emmanuel', 'Macron', 'traveled', 'Israels', 'Yad', 'Vashem', 'Holocaust', 'memorial', 'pay', 'homage', 'died', 'pledge', 'never'], ['The', 'actual', 'anniversary', 'liberation', 'Auschwitz', 'least', 'million', 'slaughtered', 'Nazi', 'death', 'camp', 'marked', 'Monday', 'Poland', 'In', 'Israel', 'though', 'noticeable', 'absentees', 'succession', 'contretemps', 'Poland', 'Lithuania', 'example', 'accused', 'Putin', 'reviving', 'Stalinist', 'era', 'tropes', 'hes', 'claimed', 'Soviet', 'Union', 'saved', 'world', 'Nazism', 'framed', 'Polish', 'people', 'participating', 'Holocaust'], ['So', 'Putin', 'given', 'speaking', 'role', 'Yad', 'Vashem', 'Presidents', 'Andrzej', 'Duda', 'Poland', 'Lithuanias', 'Gitanas', 'Nauseda', 'declined', 'attend', 'Meanwhile', 'French', 'President', 'Emmanuel', 'Macron', 'got', 'minor', 'shouting', 'match', 'Israeli', 'police', 'sought', 'enter', 'medieval', 'Church', 'Saint', 'Anne', 'Jerusalem', 'French', 'territory', 'since', 'th', 'century', 'ahead', 'French', 'leader'], ['Notably', 'nearly', 'identical', 'incident', 'happened', 'late', 'French', 'President', 'Jacques', 'Chirac', 'Later', 'however', 'group', 'photo', 'world', 'leaders', 'home', 'Israeli', 'President', 'Reuven', 'Rivlin', 'Macron', 'strategically', 'pictured', 'front', 'center', 'hosts', 'Rivlin', 'Prime', 'Minister', 'Benjamin', 'Netanyahu', 'In', 'fight', 'political', 'life', 'indictment', 'corruption', 'facing', 'new', 'elections', 'March', 'Netanyahu', 'making', 'weeks', 'events'], ['He', 'even', 'leaned', 'role', 'statesman', 'strolling', 'television', 'cameras', 'Putin', 'taking', 'visit', 'mother', 'Naama', 'Issachar', 'Israeli', 'American', 'woman', 'imprisoned', 'Russia', 'This', 'awkward', 'moment', 'leader', 'country', 'keeping', 'womans', 'child', 'prison', 'one', 'issues', 'facing', 'Putin', 'ceremonies'], ['He', 'must', 'decide', 'whether', 'free', 'Issachar', 'serving', 'seven', 'half', 'years', 'prison', 'marijuana', 'found', 'luggage', 'transited', 'Moscow', 'airport'], ['Issachar', 'maintains', 'drugs', 'planted', 'forced', 'signing', 'false', 'confession'], ['Israeli', 'media', 'suggested', 'Putin', 'demanding', 'number', 'gestures', 'Israel', 'Putin', 'agrees', 'release', 'decision', 'seems', 'increasingly', 'likely', 'high', 'octane', 'campaign', 'behalf', 'And', 'Paris', 'Macron', 'facing', 'demands', 'reiterated', 'Netanyahu', 'meeting', 'deal', 'murder', 'Sarah', 'Halimi', 'year', 'old', 'French', 'Jew', 'thrown', 'Paris', 'apartment', 'window'], ['A', 'French', 'court', 'ruled', 'killer', 'criminally', 'responsible'], ['Despite', 'court', 'ruling', 'many', 'protesters', 'France', 'believe', 'killing', 'Halimi', 'anti', 'Semitic', 'act', 'Meanwhile', 'Macron', 'well', 'leaders', 'across', 'globe', 'broader', 'range', 'issues', 'address', 'regarding', 'growing', 'anti', 'Semitism'], ['The', 'Conference', 'Jewish', 'Material', 'Claims', 'Against', 'Germany', 'nearly', 'year ...

# %% [markdown]
# Now create a function that preperocesses a newspaper

# %%
def preprocess_newspaper(newspaper, newspaper_dict):
    newspaper_dict[f"{newspaper}article_list"] = []
    for article_data in newspaper:
        article = article_data['text']
        newspaper_dict[f"{newspaper}article_list"].append(preprocess_article(article))  # appends preproccessed articles to newspaper's article list
    return newspaper_dict

# %%
# Lets try with CNN
newspaper = data["cnn.com"]
newspaper_dict = {}
preprocess_newspaper(newspaper, newspaper_dict)
print(newspaper_dict)
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# Iterate over each newspaper dictionary {key: value} key = newspaper, value = articles associated with the newspaper
#
# Use spacy for higher accuracy and nltk for efficiency

# %%
# TODO: make a tokenizer function
# white space tokenization
# punctuation based tokenziation
# TreeBank tokenization

def tokenizer(json_file):
# initialize an empty dictionary to have newspaper names as keys as, words published in that newspaper as value
newspaper_articles = {}

for newspaper, articles in data.items():
    print(f"Newspaper: {newspaper}")
    sentences = [] # List to hold texts of articles for this newspaper
    for article in articles:
        text = article.get("text")
        if text:
            sentences.extend(sent_tokenize(text))

    # tokenize sentences word by word         
    words = []
    # Loop through each sentence in the list of sentences
    for sentence in sentences:
        # Split the sentence into individual words
        word_list = sentence.split()

        # Filter out words that are in stop_words
        filtered_words = []
        for word in word_list:
            parts = word.split(".")
            # Convert the word to lowercase to ensure case-insensitive matching
            for part in parts: #each part is actually a word
                if part.lower() not in stop_words and part.lower() != "'" and part.lower() != "":
                    filtered_words.append(part)

        # Add the filtered list of words to the main words list
        words.append(filtered_words)

    #add newspaper_name: texts from that newspaper as a new key value pair 
    newspaper_articles[newspaper] = words
    # print the length of the corpus
    print("corpus size: " + str(len(newspaper_articles[newspaper])))

# %%
# TODO: delete this part after tokenizer is done
# initialize an empty dictionary to have newspaper names as keys as, words published in that newspaper as value
newspaper_articles = {}

for newspaper, articles in data.items():
    print(f"Newspaper: {newspaper}")
    sentences = [] # List to hold texts of articles for this newspaper
    for article in articles: 
        text = article.get("text")
        if text:
            sentences.extend(sent_tokenize(text))
   
    # tokenize sentences word by word         
    words = []
    # Loop through each sentence in the list of sentences
    for sentence in sentences:
        # Split the sentence into individual words
        word_list = sentence.split()
    
        # Filter out words that are in stop_words
        filtered_words = []
        for word in word_list:
            parts = word.split(".")
            # Convert the word to lowercase to ensure case-insensitive matching
            for part in parts: #each part is actually a word
                if part.lower() not in stop_words and part.lower() != "'" and part.lower() != "":
                    filtered_words.append(part)
        
        # Add the filtered list of words to the main words list
        words.append(filtered_words)
        
    #add newspaper_name: texts from that newspaper as a new key value pair 
    newspaper_articles[newspaper] = words 
    # print the length of the corpus
    print("corpus size: " + str(len(newspaper_articles[newspaper])))
# Out:
# Newspaper: https://nytimes.com
# corpus size: 4406
# Newspaper: https://washingtonpost.com
# corpus size: 3605
# Newspaper: https://usatoday.com
# corpus size: 10794
# Newspaper: https://wsj.com
# corpus size: 0
# Newspaper: https://latimes.com
# corpus size: 4160
# Newspaper: https://nypost.com
# corpus size: 3612
# Newspaper: https://chicagotribune.com
# corpus size: 3545
# Newspaper: https://bostonglobe.com
# corpus size: 10604
# Newspaper: https://sfchronicle.com
# corpus size: 0
# Newspaper: https://dallasnews.com
# corpus size: 7308
# Newspaper: https://houstonchronicle.com
# corpus size: 0
# Newspaper: https://inquirer.com
# corpus size: 0
# Newspaper: https://startribune.com
# corpus size: 18
# Newspaper: https://seattletimes.com
# corpus size: 0
# Newspaper: https://miamiherald.com
# corpus size: 0
# Newspaper: https://freep.com
# corpus size: 4324
# Newspaper: https://denverpost.com
# corpus size: 1645
# Newspaper: https://orlandosentinel.com
# corpus size: 3659
# Newspaper: https://azcentral.com
# corpus size: 3264
# Newspaper: https://baltimoresun.com
# corpus size: 620
# Newspaper: https://sacbee.com
# corpus size: 0
# Newspaper: https://sandiegouniontribune.com
# corpus size: 1661
# Newspaper: https://stltoday.com
# corpus size: 2255
# Newspaper: https://tampabay.com
# corpus size: 685
# Newspaper: https://cleveland.com
# corpus size: 110
# Newspaper: https://kansascity.com
# corpus size: 0
# Newspaper: https://charlotteobserver.com
# corpus size: 0
# Newspaper: https://post-gazette.com
# corpus size: 25
# Newspaper: https://tennessean.com
# corpus size: 3686
# Newspaper: https://ajc.com
# corpus size: 213
# Newspaper: https://dispatch.com
# corpus size: 3776
# Newspaper: https://cincinnati.com
# corpus size: 4162
# Newspaper: https://indystar.com
# corpus size: 2923
# Newspaper: https://jsonline.com
# corpus size: 3232
# Newspaper: https://newsobserver.com
# corpus size: 0
# Newspaper: https://oregonlive.com
# corpus size: 0
# Newspaper: https://courier-journal.com
# corpus size: 3639
# Newspaper: https://desmoinesregister.com
# corpus size: 3221
# Newspaper: https://reviewjournal.com
# corpus size: 7868
# Newspaper: https://palmbeachpost.com
# corpus size: 4195
# Newspaper: https://fresnobee.com
# corpus size: 0
# Newspaper: https://staradvertiser.com
# corpus size: 2420
# Newspaper: https://sltrib.com
# corpus size: 0
# Newspaper: https://oklahoman.com
# corpus size: 3257
# Newspaper: https://star-telegram.com
# corpus size: 0
# Newspaper: https://nola.com
# corpus size: 536
# Newspaper: https://richmond.com
# corpus size: 1250
# Newspaper: https://abqjournal.com
# corpus size: 123
# Newspaper: https://commercialappeal.com
# corpus size: 3279
# Newspaper: https://buffalonews.com
# corpus size: 2081
# Newspaper: https://theistanbulchronicle.com
# corpus size: 568

# %% [markdown]
# Print a newspaper corpus to control the output

# %%
print(newspaper_articles.get("https://nytimes.com"))
# Out:
# [['Card', '1', '305', 'Minutes', 'Make', 'Love', 'Alice', 'ColtraneWe', 'asked', 'writers,', 'critics', 'musicians', 'including', 'Meshell', 'Ndegeocello', 'Angel', 'Bat', 'Dawid', 'tell', 'us', 'moves', 'Coltranes', 'spiritual', 'jazz', 'Background', 'Image:', 'colorful', 'animated', 'illustration', 'musician', 'loose', 'resemblance', 'Alice', 'Coltrane', 'playing', 'harp', 'eyes', 'closed'], ['Submissions', 'open', 'Submissions', 'temporarily', 'close', 'starting', 'November', '4,', '2024', 'reopen', 'January', '3,', '2025'], ['review', 'already', 'submitted', 'puzzles', 'period,', 'may', 'still', 'hear', 'us', 'submissions', 'closed', 'New', 'York', 'Times', 'crossword', 'collaboration', 'staff', 'editors,', 'seek', 'preserve', 'voice', 'making', 'puzzle', 'enjoyable', 'possible', 'solvers'], ['page', 'guidelines', 'living', 'document', 'reflects', 'current', 'best', 'practices', 'crossword', 'construction', 'summary', 'look', 'for:Lively', 'fill,', 'words,', 'phrases', 'names', 'solvers', 'know', 'infer', 'crossings', 'Original,', 'on-target', 'clues,', 'pitched', 'puzzles', 'intended', 'difficulty', 'level,', 'including', 'variety', 'cultural', 'reference', 'points', 'three', 'puzzles', 'pending', 'time', 'could', 'use', 'of:', 'Thursday', 'Sunday', 'puzzles', 'dont', 'involve', 'rebus', 'Submission', 'GuidelinesThemesThemes', 'fresh,', 'interesting,', 'narrowly', 'defined', 'consistently', 'applied', 'throughout', 'puzzle'], ['example,', 'theme', 'includes', 'particular', 'kind', 'pun,', 'puns', 'kind'], ['Themes', 'theme', 'entries', 'accessible', 'everyone'], ['generally', 'prefer', 'puzzles', 'playful', 'themes', 'rather', 'straightforward', 'subjects'], ['largest', 'deadliest', 'war', 'Europe', 'since', 'end', 'World', 'War', 'II', 'third', 'year,', 'scale', 'devastation', 'wrought', 'Russias', 'full-scale', 'invasion', 'Ukraine', 'continues', 'mount', 'front', 'line', 'place', 'ghastly', 'violence', 'hundreds', 'thousands', 'Russian', 'Ukrainian', 'soldiers', 'killed', 'wounded,', 'according', 'conservative', 'Western', 'estimates'], ['list', 'Ukrainian', 'cities', 'towns', 'largely', 'leveled', 'ground', 'Russian', 'bombs', 'artillery', 'grows', 'passing', 'month', 'Russian', 'forces', 'moved', 'forward', 'small', 'increments,', 'sustaining', 'staggering', 'number', 'casualties', 'take', 'cities', 'like', 'Avdiivka,', 'Moscow', 'captured', 'February'], ['closing', 'nearby', 'city', 'Pokrovsk,', 'Ukrainian', 'stronghold', 'east', 'recent', 'months,', 'fighting', 'spread', 'Russian-Ukrainian', 'border', 'area'], ['early', 'May,', 'Russian', 'forces', 'launched', 'offensive', 'Ukraines', 'northeast,', 'seizing', 'several', 'settlements', 'push', 'near', 'city', 'Kharkiv'], ['August,', 'Ukrainian', 'Army', 'crossed', 'Russias', 'western', 'Kursk', 'region', 'surprise', 'assault', 'brought', 'war', 'Russian', 'territory', 'way', 'never', 'seen,', 'forcing', 'tens', 'thousands', 'civilians', 'evacuate', 'Away', 'front,', 'millions', 'Ukrainians', 'spent', 'hours', 'bomb', 'shelters', 'Russia', 'rains', 'missiles', 'drones', 'military', 'units', 'civilians', 'across', 'nation'], ['Ukraines', 'energy', 'grid,', 'severely', 'damaged,', 'working', 'sporadically'], ['Thousands', 'schools,', 'hospitals', 'cultural', 'institutions', 'damaged', 'destroyed'], ['Millions', 'lost', 'homes', 'time,', 'photographers', 'New', 'York', 'Times', 'news', 'organizations', 'chronicled', 'war,', 'capturing', 'slice', 'soldiers', 'civilians', 'experienced'], ['images,', 'photographers', 'say,', 'never', 'leave'], ['years,', 'Republican', 'activists', 'huddled', 'video', 'meetings', 'talk', 'remaking', 'democracy', 'plan', 'election'], ['New', 'York', 'Times', 'obtained', 'recordings', 'aftermath', 'Donald', 'J', 'Trumps', 'defeat', '2020,', 'one', 'election', 'lawyers', 'set', 'keep', 'lies', 'loss', 'alive', 'lawyer,', 'well-connected', 'conservative', 'named', 'Cleta', 'Mitchell,', 'knit', 'together', 'grass-roots', 'activists,', 'Republica ...

# %% [markdown]
# Train you model on the sentences. Revert back to hwo you preprocess data to increase accuracy. To dos for later:
# 1) better sentence division
# 2) more data
# 3) eliminate over-used words like "the", "a" etc.
#
# Now,let's train our word2vec on NYT data, later we can create a loop to do so for every newspaper

# %%
from gensim.models import Word2Vec

# Prepare sentences for Word2Vec
sentences = newspaper_articles.get("https://nytimes.com")  # Each newspaper's corpus is one "document"
print(sentences)
# Train Word2Vec model
model = Word2Vec(sentences=sentences, vector_size=100, window=5, min_count=1, workers=4)
# Out:
# [['Card', '1', '305', 'Minutes', 'Make', 'Love', 'Alice', 'ColtraneWe', 'asked', 'writers,', 'critics', 'musicians', 'including', 'Meshell', 'Ndegeocello', 'Angel', 'Bat', 'Dawid', 'tell', 'us', 'moves', 'Coltranes', 'spiritual', 'jazz', 'Background', 'Image:', 'colorful', 'animated', 'illustration', 'musician', 'loose', 'resemblance', 'Alice', 'Coltrane', 'playing', 'harp', 'eyes', 'closed', ''], ['Submissions', 'open', 'Submissions', 'temporarily', 'close', 'starting', 'November', '4,', '2024', 'reopen', 'January', '3,', '2025', ''], ['review', 'already', 'submitted', 'puzzles', 'period,', 'may', 'still', 'hear', 'us', 'submissions', 'closed', 'New', 'York', 'Times', 'crossword', 'collaboration', 'staff', 'editors,', 'seek', 'preserve', 'voice', 'making', 'puzzle', 'enjoyable', 'possible', 'solvers', ''], ['page', 'guidelines', 'living', 'document', 'reflects', 'current', 'best', 'practices', 'crossword', 'construction', 'summary', 'look', 'for:Lively', 'fill,', 'words,', 'phrases', 'names', 'solvers', 'know', 'infer', 'crossings', 'Original,', 'on-target', 'clues,', 'pitched', 'puzzles', 'intended', 'difficulty', 'level,', 'including', 'variety', 'cultural', 'reference', 'points', 'three', 'puzzles', 'pending', 'time', 'could', 'use', 'of:', 'Thursday', 'Sunday', 'puzzles', 'dont', 'involve', 'rebus', 'Submission', 'GuidelinesThemesThemes', 'fresh,', 'interesting,', 'narrowly', 'defined', 'consistently', 'applied', 'throughout', 'puzzle', ''], ['example,', 'theme', 'includes', 'particular', 'kind', 'pun,', 'puns', 'kind', ''], ['Themes', 'theme', 'entries', 'accessible', 'everyone', ''], ['generally', 'prefer', 'puzzles', 'playful', 'themes', 'rather', 'straightforward', 'subjects', ''], ['largest', 'deadliest', 'war', 'Europe', 'since', 'end', 'World', 'War', 'II', 'third', 'year,', 'scale', 'devastation', 'wrought', 'Russias', 'full-scale', 'invasion', 'Ukraine', 'continues', 'mount', 'front', 'line', 'place', 'ghastly', 'violence', 'hundreds', 'thousands', 'Russian', 'Ukrainian', 'soldiers', 'killed', 'wounded,', 'according', 'conservative', 'Western', 'estimates', ''], ['list', 'Ukrainian', 'cities', 'towns', 'largely', 'leveled', 'ground', 'Russian', 'bombs', 'artillery', 'grows', 'passing', 'month', 'Russian', 'forces', 'moved', 'forward', 'small', 'increments,', 'sustaining', 'staggering', 'number', 'casualties', 'take', 'cities', 'like', 'Avdiivka,', 'Moscow', 'captured', 'February', ''], ['closing', 'nearby', 'city', 'Pokrovsk,', 'Ukrainian', 'stronghold', 'east', 'recent', 'months,', 'fighting', 'spread', 'Russian-Ukrainian', 'border', 'area', ''], ['early', 'May,', 'Russian', 'forces', 'launched', 'offensive', 'Ukraines', 'northeast,', 'seizing', 'several', 'settlements', 'push', 'near', 'city', 'Kharkiv', ''], ['August,', 'Ukrainian', 'Army', 'crossed', 'Russias', 'western', 'Kursk', 'region', 'surprise', 'assault', 'brought', 'war', 'Russian', 'territory', 'way', 'never', 'seen,', 'forcing', 'tens', 'thousands', 'civilians', 'evacuate', 'Away', 'front,', 'millions', 'Ukrainians', 'spent', 'hours', 'bomb', 'shelters', 'Russia', 'rains', 'missiles', 'drones', 'military', 'units', 'civilians', 'across', 'nation', ''], ['Ukraines', 'energy', 'grid,', 'severely', 'damaged,', 'working', 'sporadically', ''], ['Thousands', 'schools,', 'hospitals', 'cultural', 'institutions', 'damaged', 'destroyed', ''], ['Millions', 'lost', 'homes', 'time,', 'photographers', 'New', 'York', 'Times', 'news', 'organizations', 'chronicled', 'war,', 'capturing', 'slice', 'soldiers', 'civilians', 'experienced', ''], ['images,', 'photographers', 'say,', 'never', 'leave', ''], ['years,', 'Republican', 'activists', 'huddled', 'video', 'meetings', 'talk', 'remaking', 'democracy', 'plan', 'election', ''], ['New', 'York', 'Times', 'obtained', 'recordings', 'aftermath', 'Donald', 'J', '', 'Trumps', 'defeat', '2020,', 'one', 'election', 'lawyers', 'set', 'keep', 'lies', 'loss', 'alive', 'lawyer,', 'well-connected', 'conservative', 'named', 'Cleta',  ...

# %%
# Get the vector for a word
vector = model.wv["Israel"]

# Find most similar words
similar_words = model.wv.most_similar("Israel")
print(similar_words)
# Out:
# [('said', 0.9992824792861938), ('could', 0.9992679357528687), ('one', 0.9992677569389343), ('time', 0.9992632865905762), ('', 0.9992598295211792), ('would', 0.9992520213127136), ('made', 0.9992349743843079), ('make', 0.9992130398750305), ('also', 0.9991971850395203), ('people', 0.9991776347160339)]

# %% [markdown]
# Currently, the similar vector are from high-frequency words like "and","which" etc. I had seen lists online that had
# all of these words that we should eliminate. I will find the list, get back on the problem and test out what will be
# the similar words. If the output is still unrelated, then I will see how many times the word we want to find out is
# mentioned in our corpus. If it is too low, we might have to expend the corpus.
# I might also use wikipedia corpus (news_unrelated) to test our hyptohesis.
