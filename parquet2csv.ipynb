# %%
import glob
import os
import polars as pl

# %%
# List all of the publishers
def print_all_english_publishers(folder_path: str):
    """
    1. Scans all .parquet files in `folder_path` using Polars' lazy mode.
    2. Filters rows where language == 'en'.
    3. Collects *unique* publishers and prints them.
    """
    parquet_files = glob.glob(os.path.join(folder_path, "*.parquet"))
    if not parquet_files:
        print(f"No Parquet files found in: {folder_path}")
        return

    all_english_publishers = set()

    for pq_file in parquet_files:
        print(f"Scanning file: {pq_file}")
        # Lazily read each Parquet file
        lazy_df = pl.scan_parquet(pq_file)

        # Filter for rows in English and collect unique publishers
        pubs_df = (
            lazy_df
            .filter(pl.col("language") == "en")
            .select(pl.col("publisher").unique())
            .collect()
        )
        # Extract the publishers from the Polars DataFrame column
        pubs_list = pubs_df["publisher"].to_list()
        # Add them to our global set (avoid duplicates across multiple files)
        all_english_publishers.update(pubs_list)

    # Print all unique publishers that publish in English
    if all_english_publishers:
        print("\nAll publishers that publish in English:")
        for pub in sorted(all_english_publishers):
            print(pub)
    else:
        print("\nNo publishers found that publish in English.")
def main():
    # Replace with your actual directory path.
    # Use an r-string (raw string), escaped backslashes, or forward slashes on Windows.
    folder_path = r"C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024"

    print_all_english_publishers(folder_path)

if __name__ == "__main__":
    main()
# Out:
# Scanning file: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0000.parquet
# Scanning file: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0001.parquet
# Scanning file: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0002.parquet
# Scanning file: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0003.parquet
# Scanning file: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0004.parquet
# Scanning file: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0005.parquet
# Scanning file: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0006.parquet
# Scanning file: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0007.parquet
# Scanning file: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0008.parquet
# Scanning file: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0009.parquet
# Scanning file: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0010.parquet
# Scanning file: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0011.parquet
# Scanning file: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0012.parquet
# Scanning file: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0013.parquet
# Scanning file: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0014.parquet
# Scanning file: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0015.parquet
# Scanning file: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0016.parquet
# Scanning file: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0017.parquet
# Scanning file: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0018.parquet
# Scanning file: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0019.parquet
# Scanning file: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0020.parquet
# Scanning file: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0021.parquet
# Scanning file: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0022.parquet
# Scanning file: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0024.parquet
# Scanning file: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0025.parquet
# Scanning file: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0026.parquet
# Scanning file: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0027.parquet
# Scanning file: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0028.parquet
# Scanning file: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0029.parquet
# Scanning file: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0030.parquet
# Scanning file: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0031.parquet
# Scanning file: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0032.parquet
#
# All publishers that publish in English:
# 01net.it
# 1000wordsmag.com
# 1010wcsi.com
# 1010xl.com
# 1019therock.com
# 1033theeagle.com
# 1033thegoat.com
# 1053rnb.com
# 1063thegroove.com
# 1065jackfm.com
# 1075koolfm.com
# 1075thefan.com
# 10news.com
# 10play.com.au
# 10sballs.com
# 12onyourside.com
# 1390granitecitysports.com
# 13abc.com
# 14news.com
# 14ymedio.com
# 159.203.144.98
# 167.172.235.218
# 1785farmdog.toast.site
# 1854.photography
# 18doors.org
# 19thnews.org
# 1arabia.com
# 1to1media.com
# 209.97.146.137
# 21alivenews.com
# 225batonrouge.com
# 24-horas.mx
# 24.hu
# 24.kg
# 247ureports.com
# 247wallst.com
# 248am.com
# 24hourhiphop.com
# 263chat.com
# 280living.com
# 29news.com
# 2duerighe.com
# 2hd.com.au
# 2ndsmartestguyintheworld.com
# 2paragraphs.com
# 303magazine.com
# 3blmedia.com
# 3dprint.com
# 3dprintingindustry.com
# 3morerounds.com
# 3news.com
# 3newsnow.com
# 3rddegree.net
# 3wz.com
# 404media.co
# 411mania.com
# 44.236.173.26
# 44.241.83.70
# 49ers.com
# 4barsrest.com
# 4semanas.com
# 512pixels.net
# 52.33.192.141
# 52.39.43.255
# 52.40.95.94
# 52.89.83.123
# 54.244.128.156
# 54.245.132.35
# 580wibw.com
# 604now.com
# 610cktb.com
# 610kona.com
# 6abc.com
# 702.co.za
# 721news.com
# 7news.com.au
# 890kdxu.com
# 8bitdo.com
# 8newsnow.com
# 911revision.substack.com
# 923wil.com
# 929theticket.com
# 92q.com
# 95wiilrock.com
# 971theriver.com
# 97xonline.com
# 989xfm.ca
# 995qyk.com
# 999wefm.com
# 99percentinvisible.org
# 9and10news.com
# 9news.com.au
# 9now.nine.com.au
# 9to5google.com
# 9to5linux.com
# 9to5mac.com
# 9to5toys.com
# a-lyric.com
# a.wholelottanothing.org
# a16zcrypto.substack.com
# a1plus.am
# a2zsoccer.com
# aa.com.tr
# aan.org
# aap.com.au
# aaronebooksgamesandmore.com
# aaronkheriaty.substack.com
# aaronsiri.substack.com
# aarp.org
# aarpdriversafety.org
# abante.com.ph
# abasto.com
# abbotsfordtoday.ca
# abbyjanebakes.com
# abc-7.com
# abc.com
# abc.net.au
# abc10up.com
# abc11.com
# abc13.com
# abc15.com
# abc27.com
# abc30.com
# abc4.com
# abc7.com
# abc7chicago.com
# abc7news.com
# abc7ny.com
# abcactionnews.com
# abcdrduson.com
# abcmoney.co.uk
# abcnews.go.com
# abd.org.uk
# abergavennychronicle.com
# abilenescene.com
# abitare.it
# abnnewswire.net
# abortretry.fail
# about.fb.com
# about.gitlab.com
# aboutamazon.com
# aboutmyarea.co.uk
# abrightideaonline.com
# absolutegeeks.com
# abu.org.my
# accandengineering.com
# acceleratelearning.stanford.edu
# acceptablecollateraldamage.substack.com
# accessaa.co.uk
# accessonline.com
# accidentaldeliberations.blogspot.com
# accuweather.com
# acemagazinelex.com
# acento.com.do
# aceshowbiz.com
# acmepackingcompany.com
# acmilan.theoffside.com
# acousticguitar.com
# acranger.com
# actionforex.com
# actionnews5.com
# actionnewsjax.com
# actualidad.rt.com
# actualno.com
# actusnews.com
# acuoptimist.com
# adaderana.lk
# adage.com
# addictedtoquack.com
# addisstandard.com
# adexchanger.com
# adherents.com
# adifferentbeastlv.com
# adirondackexplorer.org
# admiralmarkets.com
# admiralmarkets.sc
# adnkronos.com
# adomonline.com
# advanced-television.com
# advancetitan.com
# adventuregamers.com
# adventuresnw.com
# adversus.com
# advertisernewsnorth.com
# advertisernewssouth.com
# advnture.com
# advocate.com
# adweek.com
# adworld.ie
# aella.substack.com
# aerotechnews.com
# aescripts.com
# afa.org
# afaqs.com
# afar.com
# afl.com.au
# afr.com
# aframnews.com
# africa.espn.com
# african.business
# africanagenda.net
# africanews.com
# africanexaminer.com
# afterbabel.com
# afterhourslacrosse.ca
# aftermath.site
# afternoonvoice.com
# agairupdate.com
# agcnews.eu
# agcrops.osu.edu
# agenparl.eu
# agentsrealtyfl.com
# agenziagiornalisticaopinione.it
# ageofmuses.substack.com
# aggiecentral.com
# agi.it
# agilitreerecruiting.com
# agmetalminer.com
# agnetwest.com
# agribusiness.hu
# agricultura.it
# agrigentooggi.it
# agriland.ie
# agrowingculture.substack.com
# ahundredfallingveils.com
# ai-online.com
# aicr.org
# aiguyus.godaddysites.com
# aijac.org.au
# aim4truth.org
# aircargonext.com
# aircargotechsummit.com
# aircourieruk.com
# airforce-technology.com
# airforcetimes.com
# airwaysmag.com
# aislingoloughlin.substack.com
# aitcofficial.org
# ajc.com
# akademie.dw.com
# aknewsfeed.com
# akronlife.com
# aktiencheck.de
# aktuality.sk
# akweb.de
# alabama.forums.rivals.com
# alabama.rivals.com
# alabamanewscenter.com
# alankandel.scienceblog.com
# alaska-native-news.com
# alaskapublic.org
# alaskasnewssource.com
# albertanativenews.com
# albertapolitics.ca
# albertcory50.substack.com
# albertleatribune.com
# albionnewsonline.com
# albionpleiad.com
# alborde.com
# aldeeninsitutie.net
# aldenadvertisernews.com
# alderhospitalityllc.toast.site
# aleteia.org
# alexberenson.substack.com
# alextimes.com
# alexwasburne.substack.com
# alghad.com
# algonquintimes.com
# alicespringsnews.com.au
# aliciakennedy.news
# alistapart.com
# aljadeed.tv
# aljazeera.com
# all-andorra.com
# all-noise.co.uk
# allaboutcookies.org
# allaboutthejersey.com
# allafrica.com
# allatsea.net
# allclassical.org
# alleastafrica.com
# alleghenyfront.org
# alleyoop.ilsole24ore.com
# allforxi.com
# allhawaiinews.com
# allhiphop.com
# alliancevita.org
# allisrael.com
# allotsego.com
# allpakistaninews.com
# allstarcardssantee.com
# allthatsinteresting.com
# alltogethernow.org.uk
# almanacnews.com
# almesryoon.com
# alphanewscall.com
# alpinecom.net
# alsumaria.tv
# altadensidad.com
# altassets.net
# altenergymag.com
# alvaradoinc190.com
# alvinhermans.itch.io
# alwafd.news
# alwaysknownjewelry.com
# alwaysmountaintime.com
# alzheimersnewstoday.com
# am1150.ca
# am800cklw.com
# amandakuntzpo.com
# amandala.com.bz
# amateurphotographer.com
# amazinavenue.com
# ameliaislandliving.com
# america.substack.com
# americaamerica.news
# americanbankingnews.com
# americancityandcounty.com
# americandrugdiscovery.com
# americanfreepress.net
# americanhandgunner.com
# americanhorsepubs.org
# americanjournalnews.com
# americanmotorcyclist.com
# americanpolicy.org
# americanpressinstitute.org
# americanprestigepod.com
# americansongwriter.com
# americanthinker.com
# americantowns.com
# americanwritersmuseum.org
# americateve.com
# americustimesrecorder.com
# amerks.com
# amnesty.ie
# amny.com
# amruthaharauthenticindianfood.toast.site
# amsterdam-spoke.com
# amsterdamnews.com
# amusementtoday.com
# anacortesnow.com
# analisidifesa.it
# anamihalceamdphd.substack.com
# anandamide.substack.com
# anandtech.com
# ananova.com
# anchorofgold.com
# ancient-code.com
# ancientoriginsunleashed.com
# andmagazine.substack.com
# andrewmadry.substack.com
# androidauthority.com
# androidcentral.com
# androidcure.com
# androidguys.com
# androidpolice.com
# androidshock.com
# andscape.com
# andthevalleyshook.com
# aneeskitchen.com
# anewdomain.net
# anews.com.tr
# anfield-online.co.uk
# angelschinahouse.com
# angelusnews.com
# angiesjamaicangrill.com
# anglican.ca
# anglicanjournal.com
# angrybearblog.com
# anguscountyworld.co.uk
# anigamers.com
# anildash.com
# animatedviews.com
# animationxpress.com
# animemojo.com
# animenewsnetwork.com
# animoto.com
# anitabaxasmd.substack.com
# anitabora.com
# annanews.com
# annastableleominster.com
# anneapplebaum.com
# annebyrn.substack.com
# annehelen.substack.com
# anokhilife.com
# anonymouseagle.com
# ansonrecord.com
# antarcticajournal.com
# antena3.ro
# anthonycolpo.substack.com
# antigotimes.com
# antiguaobserver.com
# antimusic.com
# antiochherald.com
# antiquesandthearts.com
# antiquestradegazette.com
# antonchaitkin.substack.com
# antonmediagroup.com
# antsmarching.org
# aol.com
# aopnews.com
# aparc.fsi.stanford.edu
# apartmenttherapy.com
# aplebessite.com
# apollographql.com
# apolyton.net
# app.com.pk
# appadvice.com
# apparelinsiders.com
# apparelnews.net
# appetitomagazine.com
# apple.slashdot.org
# appleinsider.com
# appmaster.io
# apps.apple.com
# apps.bostonglobe.com
# apps.npr.org
# apps.texastribune.org
# apr.org
# apricitas.io
# aptn.ca
# aptntv.ca
# aquaculturenorthamerica.com
# arab48.com
# arabamericannews.com
# arabianbusiness.com
# arablit.org
# arabnews.com
# aranews.net
# araratadvertiser.com.au
# arbesman.substack.com
# arcanealloydice.com
# arcdigital.media
# archaeology.org
# archbalt.org
# archdaily.com
# archiecomics.com
# archined.nl
# architecturalrecord.com
# architecturebois.fr
# architecturenotes.co
# arcocafe.com
# arctic-news.blogspot.com
# arcticicehockey.com
# arcticnow.com
# arctictoday.com
# areanews.com.au
# arena.org.au
# argonautnewspaper.com
# argophilia.com
# argyllshireadvertiser.co.uk
# arianatelevision.com
# arizona.forums.rivals.com
# arizona.rivals.com
# arizonamilk.org
# arizonasports.com
# arizonastate.rivals.com
# arizonatalks.org
# arizonavarsity.rivals.com
# arkansas.forums.rivals.com
# arkansas.rivals.com
# arkansasonline.com
# arkansasstate.rivals.com
# arktimes.com
# arlnow.com
# armageddonprose.substack.com
# armchairdragoons.com
# armenianweekly.com
# armidaleexpress.com.au
# armoxon.substack.com
# armscontrolwonk.com
# army.rivals.com
# armytimes.com
# arnnet.com.au
# arranbanner.co.uk
# arredanegozi.it
# arrl.org
# arrowheadpride.com
# arsenal-world.co.uk
# artbusinessnews.com
# arthurfirstenberg.substack.com
# artificialcommunication.mitpress.mit.edu
# artikel-presse.de
# artsakhpress.am
# artsculture.newsandmediarepublic.org
# artshub.co.uk
# artshub.com.au
# aruba.nu
# arunachal24.in
# arunachaltimes.in
# arxiv.org
# arydigital.tv
# arynews.tv
# asadordelsur.com
# asapland.com
# asbarez.com
# asbestos.com
# ascoltaepentiti.blogspot.com
# aseaofblue.com
# asenatv.com
# ashenden.org
# ashevilledailyplanet.com
# ashevillefilmfest.com
# ashmedai.substack.com
# asiafinancial.com
# asiamoney.com
# asianlite.ae
# asianlite.com
# asianprivatebanker.com
# asiaone.com
# asiapacificreport.nz
# asiaresearchnews.com
# asiasamachar.com
# asiasentinel.com
# asiatimes.com
# ask-polly.com
# ask.metafilter.com
# askkissy.com
# askmen.com
# asktraders.com
# aspenjournalism.org
# aspenpublicradio.org
# asq.in.th
# ass-savers.com
# assamtribune.com
# associatestimes.com
# association.aap.cornell.edu
# assodigitale.it
# astanatimes.com
# asterandpinemarket.com
# astoriapost.com
# astralcodexten.com
# astronomynow.com
# atec.eventsair.com
# atefficientservice.com
# athleticsnation.com
# athleticsweekly.com
# atlanta.eater.com
# atlantablackstar.com
# atlantadailyworld.com
# atlantafalcons.com
# atlantahomesmag.com
# atlantamagazine.com
# atlantanewsfirst.com
# atlantic.ctvnews.ca
# atlanticcouncil.org
# attac.no
# attackofthefanboy.com
# atthehive.com
# attitude.co.uk
# attoday.co.uk
# attorneycox.substack.com
# atvtoday.co.uk
# au.motorsport.com
# au.news.yahoo.com
# au.sports.yahoo.com
# auburn.forums.rivals.com
# auburn.rivals.com
# augustafreepress.com
# augustman.com
# aulistings.com.au
# auralcrave.com
# aussie17.com
# aussiedlerbote.de
# austin.culturemap.com
# austin.eater.com
# austinchronicle.com
# austindailyherald.com
# austinfamily.com
# australianlendingcentre.com.au
# australianmining.com.au
# australianpropertyjournal.com.au
# australianseniorgolfer.com.au
# australianwomenonline.com
# autismparentingmagazine.com
# auto.economictimes.indiatimes.com
# auto.hindustantimes.com
# auto123.com
# autobabes.com.au
# autoblog.com
# autocar.co.uk
# autoevolution.com
# autoexpress.co.uk
# automaton-media.com
# automobilesreview.com
# automoblog.com
# automoblog.net
# automotivepowertraintechnologyinternational.com
# automotiveworld.com
# automotobookshop.com.au
# autonomoustruckers.substack.com
# autoracingdaily.com
# autos.yahoo.com
# autoserviceworld.com
# autospies.com
# autosport.com
# autospynews.net
# autostraddle.com
# avalanchepress.com
# avalara.com
# avaz.ba
# avc.com
# aventuramagazine.com
# averett.edu
# aviation24.be
# aviationpros.com
# avnetwork.com
# avweb.com
# awardsdaily.com
# awe24.com
# awfulannouncing.com
# awn.com
# awpasydneynews.blogspot.com
# awr.org
# axadletimes.com
# axcessnews.com
# axios.com
# aylmerexpress.com
# azatutyun.am
# azbuki.bg
# azcardinals.com
# azdesertswarm.com
# azernews.az
# azertag.az
# azfamily.com
# azom.com
# azsnakepit.com
# b1057.com
# b985.com
# b985radio.com
# baas.aas.org
# babel.ua
# babwnews.com
# backingthepack.com
# backpackinglight.com
# backsportspage.com
# backtothebay.net
# badgerherald.com
# badguybagels.com
# badlefthook.com
# baggagereclaim.co.uk
# bahamaspress.com
# bahamasspectator.com
# bahamasuncensored.com
# bahrainthisweek.com
# bailiwicknews.substack.com
# bajanreporter.com
# bakarfellows.berkeley.edu
# bakhtarnews.af
# bakingbusiness.com
# balderton.com
# balldurham.com
# ballerstatus.com
# balloon-juice.com
# ballparkdigest.com
# baltimorebeatdown.com
# baltimorefishbowl.com
# baltimoreravens.com
# baltimorestyle.com
# baltimoretimes-online.com
# banburyguardian.co.uk
# bandt.com.au
# bangkokpost.com
# bangladeshchronicle.net
# banglamirrornews.com
# bangordailynews.com
# bankautomationnews.com
# bankautomationsummit.com
# bankerandtradesman.com
# bankingjournal.aba.com
# bankrate.com
# bankspost.com
# banneroftruth.org
# bannersontheparkway.com
# bantop.org
# banyanhill.com
# banyuleandnillumbikweekly.com.au
# baonghean.vn
# baptistcourier.com
# baptistnews.com
# barbadosgazette.com
# barbadosunderground.net
# barbqboutique.com
# barcablaugranes.com
# barchart.com
# bareta.news
# barnesandnoble.com
# barnsider.com
# barrie.ctvnews.ca
# barristermagazine.com
# barsoom.substack.com
# bartlett-express.com
# bartonchronicle.com
# basementmedicine.org
# basketballinsiders.com
# basketballrecruiting.rivals.com
# basketballshorts.substack.com
# basketinside.com
# basketuniverso.it
# bassbuilt.itch.io
# batemansbaypost.com.au
# batterypower.com
# battingwithbimal.com
# battleredblog.com
# baucemag.com
# bavarianfootballworks.com
# bayarea.com
# bayareaobserver.com
# baylorlariat.com
# baywindows.com
# bbbtv12.com
# bbc.bm
# bbjtoday.com
# bbqonline.co.za
# bc.ctvnews.ca
# bcbradio.co.uk
# bcgeu.ca
# bcheights.com
# bcinterruption.com
# bcktaxservices.com
# bclions.com
# bcpioneer.com
# bd24live.com
# bdcmagazine.com
# bdcrictime.com
# bdnews24.com
# bdnewstimes.com
# bdonline.co.uk
# bdrecorder.co.uk
# beachconnection.net
# beachmetro.com
# beaconhilltimes.com
# beat102103.com
# beatradar.com
# beauty.beautyandlace.net
# beautyandlace.net
# beavercountian.com
# beavercreeknewscurrent.com
# beckersasc.com
# beckershospitalreview.com
# beckerspayer.com
# beckmesser.info
# bedfordtoday.co.uk
# beebom.com
# beeley.substack.com
# beernet.com
# beforesandafters.com
# begadistrictnews.com.au
# behance.net
# behindthehedges.com
# behindthesteelcurtain.com
# beinghunted.de
# belairnewsandviews.com
# belfastlive.co.uk
# belfastmedia.com
# believersportal.com
# bellanaija.com
# bellbet.com
# bellefairkitchen.toast.site
# bellevilleareaindependent.com
# bellevillemessenger.org
# bellevueboards.com
# bellingcat.com
# beloit.edu
# beloitcollegeroundtable.com
# belonging.berkeley.edu
# benchmarkmonitor.com
# bendigoadvertiser.com.au
# bendsource.com
# bengals.com
# benitolink.com
# benzinga.com
# berkeleyside.org
# bernardgoldberg.com
# berthoudrecorder.com
# bes-reporter.com
# bestcards.com
# bestcolleges.com
# bestlifeonline.com
# bet.com
# betakit.com
# betanews.com
# bethelks.edu
# betterdwelling.com
# betting.betfair.com
# beverlypress.com
# bevnet.com
# beyondchron.org
# beyondhogwarts.com
# beyondsecurity.com
# beyondtheflag.com
# bfcsaz.com
# bgr.com
# bhansagharut.com
# bharattimes.com
# bhaskarenterpries.com
# bhbusiness.com
# bianet.org
# bicmagazine.com
# bicommunitynews.co.uk
# bidnessetc.com
# bigbendsentinel.com
# bigblueinteractive.com
# bigblueview.com
# bigbrotherwatch.org.uk
# bigcatcountry.com
# bigcityburrito.com
# bigcountryhomepage.com
# bigdsoccer.com
# bigfredspizza.com
# biggleswadetoday.co.uk
# bighornmountainradio.com
# bigislandvideonews.com
# bigtechnology.com
# bigthink.com
# bigwestracing.com
# bikebiz.com
# bikeindia.in
# bikeportland.org
# bilkulonline.com
# billmckibben.substack.com
# billricejr.substack.com
# billwalton.substack.com
# binance.com
# binarly.io
# binghamtonhomepage.com
# binkylarue.substack.com
# biobiochile.cl
# bioethics.com
# biolabmag.com
# biologyphenom.substack.com
# biometricupdate.com
# bioprocessintl.com
# bioslevel.com
# biospace.com
# bioworld.com
# birchtree.me
# birminghammail.co.uk
# birminghamtimes.com
# bistroontheboulevard.com
# bitcoinist.com
# biteclub.perthnow.com.au
# bitecode.dev
# bitterandblue.sbnation.com
# bitterrootstar.com
# bizbash.com
# bizcommunity.africa
# bizcommunity.com
# bizepic.com
# bizmonthly.com
# biznesstransform.com
# bizneworleans.com
# biznews.com
# biztimes.com
# biztucson.com
# bizwatchnigeria.ng
# bizwest.com
# bjconline.org
# bjjheroes.com
# bjournal.com
# bjpenn.com
# bjui-journals.onlinelibrary.wiley.com
# blabbermouth.net
# blackamericaweb.com
# blackartslegacies.crosscut.com
# blackbartsbrunch.com
# blackbirdspyplane.com
# blackenterprise.com
# blackheartgoldpants.com
# blackhillsfox.com
# blacknet.co.uk
# blackoutdallas.com
# blackpoolgazette.co.uk
# blackpressusa.com
# blackshoediaries.com
# blackvoicenews.com
# blackwestchester.com
# blackwhitereadallover.com
# blackyouthproject.com
# bladenjournal.com
# blastmagazine.com
# blavity.com
# blayneychronicle.com.au
# blazersedge.com
# blc.edu
# bleacherreport.com
# bleedcubbieblue.com
# bleedingcool.com
# bleedinggreennation.com
# blenderartists.org
# blessyouboys.com
# blissandblisters.substack.com
# blisty.cz
# blockclubchicago.org
# blocksandfiles.com
# blog.3g4g.co.uk
# blog.apnic.net
# blog.archive.org
# blog.augusttable.com
# blog.chromium.org
# blog.cloudflare.com
# blog.ericgoldman.org
# blog.flickr.net
# blog.gaijinpot.com
# blog.geocities.institute
# blog.gitbutler.com
# blog.goodsam.com
# blog.hcde-texas.org
# blog.independent.org
# blog.japanwondertravel.com
# blog.johndowning.ca
# blog.jonudell.net
# blog.logrocket.com
# blog.maryannedemasi.com
# blog.merics.org
# blog.mozilla.org
# blog.nateliason.com
# blog.nightly.mozilla.org
# blog.openstreetmap.org
# blog.rescuetime.com
# blog.rust-lang.org
# blog.seamonkey-project.org
# blog.sentry.io
# blog.son-video.com
# blog.stefan-gossner.com
# blog.thunderbird.net
# blog.tmcnet.com
# blog.trailofbits.com
# blog.tutorabcchinese.com
# blog.witness.org
# blog.zulip.com
# blogabull.com
# blogchicks.com.au
# blogcritics.org
# bloggersodear.com
# bloggingdirty.com
# bloggingpro.com
# bloggingtheboys.com
# bloghouston.com
# blogs.bmj.com
# blogs.cfainstitute.org
# blogs.jccc.edu
# blogs.jpcert.or.jp
# blogs.library.duke.edu
# blogs.millersville.edu
# blogs.nicholas.duke.edu
# blogs.opentext.com
# blogto.com
# blondiesbakeryboutique.com
# bloodyelbow.com
# blueandgreentomorrow.com
# bluebirdbanter.com
# blueeaglemo.com
# bluegrasstoday.com
# bluemanhoop.com
# bluemountainsgazette.com.au
# blueridgecountry.com
# bluesock.org
# blythewoodonline.com
# bmamag.com
# bmanalysis.substack.com
# bmwblog.com
# bnamericas.com
# bne.eu
# bnet.substack.com
# bnnbloomberg.ca
# bnnbreaking.com
# bnonews.com
# boainformacao.com.br
# boardgamewire.com
# boardwalkfriesburgersshakeslansdowne.toast.site
# boatingindustry.com
# bobandtom.com
# bocabeacon.com
# bocaratontribune.com
# bocojo.com
# bodyshopbusiness.com
# bodytype.substack.com
# boereport.com
# boghossian.substack.com
# boholchronicle.com.ph
# boingboing.net
# boisestatepublicradio.org
# bol.uol.com.br
# bolavip.com
# boldlife.com
# bollettinoadapt.it
# bollywoodhungama.com
# bollywoodlife.com
# bollywoodnewsworld.com
# bolnews.com
# boltsbythebay.com
# boltsfromtheblue.com
# boluolay.com
# bombreport.com
# bonaire.nu
# boodicca.substack.com
# book.flowingdata.com
# bookforum.com
# bookgirl.beautyandlace.net
# booklife.com
# bookmarkscope.com
# bookriot.com
# boomlive.in
# boomroastedcoffeehtx.com
# boondoggle.substack.com
# boorowanewsonline.com.au
# bootlegonline.com
# bordermail.com.au
# borderreport.com
# boredpanda.com
# boriquagato.substack.com
# borkena.com
# borncity.com
# borrachosdiner.com
# borregosun.com
# bossierpress.com
# bossip.com
# boston.com
# boston25news.com
# bostoncollege.forums.rivals.com
# bostoncollege.rivals.com
# bostoncyclistsunion.org
# bostonglobe.com
# bostonhockeynow.com
# bostonmagazine.com
# bottradionetwork.com
# bouldercityreview.com
# boursorama.com
# boutiquejapan.com
# bovnews.com
# bowhunting.com
# bowienewsonline.com
# bowlingthismonth.com
# bowmanextra.com
# boxing247.com
# boxinginsider.com
# boxofficebuz.com
# boxofficecollection.in
# boxofficepro.com
# boyleheightsbeat.com
# boynegazette.com
# bp.com
# bq-magazine.com
# br.de
# braidwoodtimes.com.au
# brainhealthkitchen.substack.com
# brandequity.economictimes.indiatimes.com
# brandonreporter.com
# brandsouthafrica.com
# brasil247.com
# braunschweiger-zeitung.de
# bravewords.com
# breakfastclub51.com
# breakinglatest.news
# breakingtravelnews.com
# brecorder.com
# breezynews.com
# breitbart.com
# brentozar.com
# bresciadomani.net
# brewbound.com
# brewcrewball.com
# brewhoop.com
# brickstoneskitchenandbar.toast.site
# bridgedetroit.com
# bridgetogantry.com
# briefly.co.za
# brighteon.com
# brightlightsfilm.com
# brightonandhovenews.org
# brightside.me
# brightsideofthesun.com
# bringonthecats.com
# brisbanetimes.com.au
# brisnet.com
# bristolpost.co.uk
# brit.co
# brklynkitchen.com
# brnodaily.com
# broadbandbreakfast.com
# broadcastnow.co.uk
# broadway.com
# broadwayfillmorealive.org
# broadwayworld.com
# brooker.co.za
# brooklynpaper.com
# brooklynreporter.com
# brooksreview.net
# brothersjuddblog.com
# brotherspizzaexpressthewoodlandstx.com
# browardpalmbeach.com
# brownfieldagnews.com
# brownpundits.com
# brownsnation.com
# brownsprinter.com
# brownstone.substack.com
# brucepeninsulapress.com
# bruneinewsgazette.com
# brushymountain-smokehouse.com
# bscbengalnews.blogspot.com
# bsee.co.uk
# bsppd.business-standard.com
# btf.rappler.com
# btlj.org
# btlonline.org
# btpowerhouse.com
# buccaneers.com
# buccihomesolutions.com
# buchtelite.com
# bucknellian.net
# bucksherald.co.uk
# buckys5thquarter.com
# bucsdugout.com
# bucsnation.com
# buffalo.edu
# buffalofm.wnymedia.net
# buffalogolfer.com
# buffalohealthyliving.com
# buffaloriverreview.com
# buffalorumblings.com
# building.co.uk
# buildingslack.com
# buildingthedam.com
# buildkite.com
# bukovina.biz.ua
# bulatlat.com
# bulawayo24.com
# bullardcharger.com
# bulletsforever.com
# bullshido.net
# bumm.sk
# bunburymail.com.au
# bunkered.co.uk
# buonadomenica.substack.com
# bupipedream.com
# burgundy-report.com
# burkesbackyard.com.au
# burnham-on-sea.com
# burnleyexpress.net
# burntorangenation.com
# bursa.ro
# busineesau.org
# business-fundas.com
# business-live.co.uk
# business-standard.com
# business2community.com
# businessadvantagepng.com
# businesschief.asia
# businesschief.com
# businesschief.eu
# businessdailyafrica.com
# businessday.ng
# businessdesk.co.nz
# businessfacilities.com
# businessfirstonline.co.uk
# businessgreen.com
# businessincalgary.com
# businessincameroon.com
# businessinsider.com
# businessjournalism.org
# businesslive.co.za
# businessmirror.com.ph
# businessmk.co.uk
# businessmotoring.co.uk
# businessnewsthisweek.com
# businessnewswales.com
# businessoffashion.com
# businessplus.ie
# businesspost.ie
# businesspundit.com
# businessreport.com
# businesstimes.com.sg
# businesswest.com
# busride.com
# busseltonmail.com.au
# bustle.com
# busybeeinsure.com
# buttondown.email
# buxtonadvertiser.co.uk
# buzz.ie
# buzzfeed.com
# buzzfeednews.com
# buzzmachine.com
# bvtack.com
# bvwv.nwaonline.com
# bworldonline.com
# bxtimes.com
# bytemarkscafe.org
# bytesector.com
# byuiscroll.org
# bywords.substack.com
# c21media.net
# c4isrnet.com
# c82.net
# c895.org
# ca.finance.yahoo.com
# ca.movies.yahoo.com
# ca.news.yahoo.com
# ca.sports.yahoo.com
# ca.style.yahoo.com
# caasimada.net
# cabinradio.ca
# cabotwealth.com
# cadencedubusbrooklynstrength.substack.com
# cafelockeddown.substack.com
# cafemom.com
# cafenoir.coffee
# cagesideseats.com
# caitlinjohnst.one
# cajnewsafrica.com
# cal.forums.rivals.com
# cal.rivals.com
# cal.streetsblog.org
# calcioefinanza.it
# calcoastnews.com
# caldronpool.com
# caldwelljournal.com
# calenda.org
# calexicochronicle.com
# calgary.ctvnews.ca
# calgaryhockeynow.com
# calgaryjournal.ca
# calgarywranglers.com
# california18.com
# californiaexaminer.net
# californiahealthline.org
# californiapreps.n.rivals.com
# californiapreps.rivals.com
# californiawaterblog.com
# calitreview.com
# calltothepen.com
# calmarcourier.com
# calmatters.org
# calmdownben.com
# calvinchimes.org
# cambodianewsgazette.com
# cambrian-news.co.uk
# cambridge-news.co.uk
# cambridge.org
# camdenchat.com
# camdenhat.com
# camer.be
# cameroonconcordnews.com
# cameroonintelligencereport.com
# cameroonnewsagency.com
# cameroononline.org
# campaignasia.com
# campaignbrief.com
# campaignbriefasia.com
# campaignlive.co.uk
# campaignlive.com
# campaignsandelections.com
# campusecho.com
# campusidnews.com
# campusreel.org
# campusreform.org
# campusreview.com.au
# campussports.net
# canadianauthors.org
# canadianbusiness.com
# canadianconsultingengineer.com
# canadiancontractor.ca
# canadiandimension.com
# canadianminingjournal.com
# canadianmortgagetrends.com
# canadianshareablenews.substack.com
# canadianunderwriter.ca
# canalstreetchronicles.com
# canarias7.es
# canaryinacovidworld.substack.com
# canberra.edu.au
# canberratimes.com.au
# candgnews.com
# candicewuehle.substack.com
# canescountry.com
# canindia.com
# canishoopus.com
# cannabisnow.com
# cannonballcollection.com
# canplastics.com
# cantucorgis.com
# canyon-news.com
# canyonnews.com
# capacanada.ca
# capacitymedia.com
# capeandislands.org
# capecod.com
# capecodlife.com
# capetalk.co.za
# capgemini.com
# capilanocourier.com
# capital.cl
# capitalfm.co.ke
# capitalfm.com
# capitalmag.co.nz
# capitalxtra.com
# capoliticalreview.com
# caracaschronicles.com
# carandbike.com
# carartisanchocolate.toast.site
# carbodydesign.com
# carcomplaints.com
# cardchronicle.com
# cardealermagazine.co.uk
# cardekho.com
# cardinalnews.org
# cardinalpointsonline.com
# careerreadyindiana.com
# careers.semrush.com
# careervillage.org
# careforthefamily.org.uk
# careygillam.substack.com
# caribbeanlife.com
# caribpr.com
# caribpress.com
# carillonregina.com
# carindia.in
# carlist.my
# carmelmagazine.com
# carnicominstitute.substack.com
# carolinagelen.substack.com
# carolinapublicpress.org
# carolinecala.substack.com
# carreviewcentral.com.au
# carriagehousebakeryfoods.com
# carrollnews.org
# carsession.com
# carsuk.net
# cartermatt.com
# carthagecourier.com
# cartilagefreecaptain.sbnation.com
# cartrade.com
# carused.jp
# carwale.com
# carwash.com
# casamiapuyallup.toast.site
# cascadeae.com
# cascadebusnews.com
# cascademontana.com
# caseyliss.com
# cash.ch
# casinoplayersreport.com
# cassiuslife.com
# castanet.net
# castirontavern.com
# casualhoya.com
# catamarca24.net
# catcountry1029.com
# catcountry1073.com
# catcrave.com
# catechist.com
# catererlicensee.com
# cateringscotland.com
# cathnews.co.nz
# catholic.com
# catholic.org
# catholicherald.org
# catholicinsight.com
# catholiclife.diolc.org
# catholicmessenger.net
# catholicsun.org
# catholicweekly.com.au
# catscratchreader.com
# catwalkyourself.com
# caughtoffside.com
# causewaycrowd.com
# cavaliercountyextra.com
# cavaliersnation.com
# caymanmama.com
# caymannewsservice.com
# cbc-network.org
# cbc.ca
# cbcew.org.uk
# cbneurope.com
# cbr.com
# cbs.nl
# cbs17.com
# cbs42.com
# cbs4indy.com
# cbs7.com
# cbsnews.com
# cbssports.com
# ccc-sales.com
# cccadvocate.com
# cccvoice.com
# ccdaily.com
# ccianet.org
# ccma.org.uk
# ccwatershed.org
# cddrl.fsi.stanford.edu
# cde.news
# cdn.dmcl.biz
# cdss.berkeley.edu
# cebudailynews.inquirer.net
# cedarnews.net
# celebitchy.com
# celebrityaccess.com
# celebrityinsider.org
# celebritynetworth.com
# celebritytoob.com
# celebsnet.com
# celiafarber.substack.com
# celticsblog.com
# cemnet.com
# cenlanow.com
# censor.net
# censorednews.substack.com
# census.gov
# centcom.mil
# centralillinoisproud.com
# centraljersey.com
# centraloregondaily.com
# centralrecorder.com
# centralwesterndaily.com.au
# centreforaviation.com
# cessnockadvertiser.com.au
# cfax1070.com
# cfcr.ca
# cfl.ca
# cfpublic.org
# cfra.com
# cfrp.mitpress.mit.edu
# cgmagonline.com
# ch-it.motorsport.com
# ch.motorsport.com
# cha.house.gov
# chabad.org
# chad.co.uk
# chalkbeat.org
# championnews.com.ng
# champspizzapub.com
# chandigarhmetro.com
# change-links.org
# changingtimes.media
# channel4.com
# channel6newsonline.com
# channelasia.tech
# channelcanada.com
# channeldailynews.com
# channele2e.com
# channelfutures.com
# channelnomics.com
# channelstv.com
# chargers.com
# charlessrobertsawards.com
# charlestownbridge.com
# charlottesville.guide
# chartattack.com
# chartist.org.uk
# chartsattack.com
# chasingnature.substack.com
# chatelaine.com
# chattanoogapulse.com
# cheapinsurance.com
# cheatsheet.com
# checkyourfact.com
# cheersandgears.com
# chefnemkitchen.com
# chefskitchenrva.com
# chelmsfordweeklynews.co.uk
# chelsearecord.com
# chemicalprocessing.com
# chemistryworld.com
# chemtrails.substack.com
# chesapeakefamily.com
# cheshire-live.co.uk
# chestertelegraph.org
# chestertownspy.org
# chi.streetsblog.org
# chiangraitimes.com
# chicago.eater.com
# chicago.indymedia.org
# chicago.splashmags.com
# chicago.suntimes.com
# chicagoboyz.net
# chicagobusiness.com
# chicagocrusader.com
# chicagolawbulletin.com
# chicagomag.com
# chicagotribune.com
# chicitysports.com
# chickfactor.com
# chiefexecutive.net
# chieftalentofficer.co
# chiesaditotti.com
# chilloutradio.com
# china-business-market.com
# chinadigitaltimes.net
# chinaglobalsouth.com
# chinaheritage.net
# chinainternetwatch.com
# chinasichuanfood.com
# chinatalk.media
# chinaworker.info
# chipchick.com
# chipleybugle.com
# chireviewofbooks.com
# chitralekha.com
# chitralnews.com
# chixcw.com
# chl.ca
# chopdetroit.com
# chowhound.com
# chrisd.ca
# chrishedges.substack.com
# chrisriback.substack.com
# christiancentury.org
# christianconcern.com
# christianitydaily.com
# christianitytoday.com
# christiannews.net
# christiannewswire.com
# christianpost.com
# christiantoday.com
# christiantoday.com:443
# christiegrace.substack.com
# christinagerrard.substack.com
# christopherminson.substack.com
# christopherrufo.com
# chromeunboxed.com
# chronicle.co.zw
# chronicle.gi
# chronicleillinois.com
# chroniclelive.co.uk
# chroniclenewspaper.com
# chroniclesofhaiphong.substack.com
# chronogram.com
# chubby-baker.com
# cieonline.co.uk
# cimsec.org
# cincinnati.forums.rivals.com
# cincinnati.rivals.com
# cincinnatimagazine.com
# cincyjungle.com
# cinemablend.com
# cio-connect.co.uk
# cio.com
# cio.economictimes.indiatimes.com
# ciol.com
# ciowatercooler.co.uk
# cipelicastiklica.com
# circleid.com
# circulatingnow.nlm.nih.gov
# citinewsroom.com
# citizen.co.za
# citizen.on.ca
# citizenmatters.in
# citizenstandard.com
# citizenwire.com
# citp.princeton.edu
# citris-uc.org
# city-journal.org
# cityam.com
# cityindex.com
# citylife.capetown
# cityobservatory.org
# cityonahillpress.com
# cityparkradio.com
# cityscenecolumbus.com
# cityunslicker.co.uk
# cityweekly.net
# civics.com
# civiewnews.com
# civil.ge
# cjad800.com
# cjca.ca
# cjhopkins.substack.com
# cknnigeria.com
# clactonandfrintongazette.co.uk
# claiborneprogress.net
# clapway.com
# clareherald.com
# claremontportside.com
# clarets-mad.co.uk
# clarityonhealth.substack.com
# clarkedailynews.com
# clarkstonnews.com
# clarksvilleonline.com
# classic-american.com
# classicalmusicdaily.com
# classicalwcrb.org
# classicboat.co.uk
# classicfm.com
# classythomasmassie.substack.com
# claxtonenterprise.com
# clcha.com
# cleanfax.com
# cleantechnica.com
# clearbluewatersports.com
# clemson.forums.rivals.com
# clemson.rivals.com
# clermontsun.com
# clevelandbrowns.com
# clevelandpress.com
# clever-box.in
# clevescene.com
# clickhole.com
# clickhouse.com
# clickup.com
# clifhigh.substack.com
# climatealmanac.org
# climatebreak.org
# climateviewer.substack.com
# climbingtalshill.com
# clinchvalleytimes.net
# clintonnc.com
# clnsmedia.com
# closerweekly.com
# closetprofessor.blogspot.com
# cloud.google.com
# cloud.yandex.com
# cloudbooklet.com
# clovisroundup.com
# clubalfa.it
# clubtroppo.com.au
# clutchpoints.com
# cm-tv.pt
# cm.estate
# cmchickenoflouisville.com
# cmcmarkets.com
# cme-mec.ca
# cmegroup.com
# cmkosher.com
# cmnnews.substack.com
# cmoon.substack.com
# cmoorejournal.com
# cmt.com
# cn2.com
# cnbc.com
# cnbcafrica.com
# cne.wtf
# cnet.com
# cnn.com
# cnnpressroom.blogs.cnn.com
# cnylatinonewspaper.com
# coachweb.com
# coastalanglermag.com
# coastaldigest.com
# coastallymphaticmassage.com
# coasterbuzz.com
# cobbcountycourier.com
# cocacolaunited.com
# coconuts.co
# codcourier.org
# codecentric.de
# codelist.biz
# codewit.com
# coed.com
# coffeeandcovid.com
# coffeebarandcones.com
# cognizant.com
# coha.org
# coinagemag.com
# coindesk.com
# coininsider.com
# coinspeaker.com
# coinweek.com
# colatoday.6amcity.com
# collapselife.substack.com
# collectorsweekly.com
# colleenhuber.substack.com
# collegenews.com
# collegian.com
# collegian.tccd.edu
# collegiatestandard.com
# collider.com
# collinsvillepress.com
# collisionmax.com
# collisionweek.com
# colombiareports.com
# colombogazette.com
# colombotelegraph.com
# colorado.rivals.com
# coloradoprepreport.rivals.com
# coloradosun.com
# coloradotriathlete.com
# colormeloverly.substack.com
# colts.com
# columbuspost.com
# columnblog.com
# com-unik.info
# combatpress.com
# comicbook.com
# comicbookmovie.com
# cominghomenewcastle.sbnation.com
# commanders.com
# commentary.org
# commerce.wa.gov
# commercialcafe.com
# commercialobserver.com
# commercialrecord.com
# commondreams.org
# commonknowledgeedinburgh.substack.com
# commonplace.knowledgefutures.org
# commons.trincoll.edu
# commonwealthtimes.org
# community.reolink.com
# community.sap.com
# community.thefa.com
# community.wongcw.com
# communitybookproject.org
# communitycare.co.uk
# communitycookery.org
# communitytv.org
# compassnews.net
# complete-review.com
# complex.com
# complexiathesinker.substack.com
# computerenhance.com
# computerweekly.com
# computerworld.com
# computing.co.uk
# concatenation.org
# conceptfitnessconsultancy.co.uk
# conchovalleyhomepage.com
# concise.ng
# concordia7.com
# confidencial.digital
# confirmado.net
# congressfoundation.org
# connachttribune.ie
# connecticut.rivals.com
# connectionsmagazine.com
# connectthewatts.com
# connieschicken.com
# conservativefreepress.com
# consilium.europa.eu
# conspiracysarah.substack.com
# construction21.org
# constructionequipmentguide.com
# consult-exp.com
# contactohoy.com.mx
# contemporaryarts.mit.edu
# contemporaryjazz.com
# content-technology.com
# context.news
# contractormag.com
# contropiano.org
# conveniencestore.co.uk
# convocation.substack.com
# cookiecrayon.itch.io
# coolest-gadgets.com
# coolfeelingshvac.com
# coolhunting.com
# cooperhewitt.org
# cootamundraherald.com.au
# copiahmonitor.com
# copperarea.com
# coppercourier.com
# copyranter.substack.com
# corbettreport.substack.com
# cordcuttersnews.com
# cordeledispatch.com
# coretvnews.com
# corkbeo.ie
# cornellreview.org
# cornellsun.com
# corner.bigblueinteractive.com
# cornish-times.co.uk
# cornnation.com
# cornwalllive.com
# cornwallseawaynews.com
# coronadotimes.com
# corpezine.com
# corporate.dw.com
# corporatecrimereporter.com
# corralescomment.com
# correctionalnews.com
# corrierenazionale.it
# corrieretoscano.it
# cosmo.ph
# costa-news.com
# costablancapeople.com
# cottonwoodheightsjournal.com
# cougcenter.com
# councilestatemedia.uk
# counterpunch.org
# counton2.com
# countryfolks.com
# countrylife.co.uk
# countrylines.com
# countryman.com.au
# county10.com
# couriernews.ca
# couriertribuneonline.com
# coursera.org
# courttv.com
# covenant.livingchurch.org
# coventrytelegraph.net
# coveringkaty.com
# coveringthecorner.com
# covermagazine.co.uk
# covid-19.mitpress.mit.edu
# covidreason.substack.com
# covnews.com
# cowboycountrymagazine.com
# cowleypress.com
# cowraguardian.com.au
# coxobodycare.com
# coyotechronicle.net
# cp24.com
# cpd.org.au
# cpfc.co.uk
# cphmag.com
# cphpost.dk
# cpomagazine.com
# cpr.org
# cpu.org.uk
# crabcowboyz.com
# craftbeerwine.net
# crain.com
# craincurrency.com
# crainsdetroit.com
# crainsgrandrapids.com
# crainsnewyork.com
# cranescraftbbq.com
# crash.net
# cravewellcafe.com
# crawfishboxes.com
# crawfordmediagroup.net
# crazybbq.com
# creativebloq.com
# creativesamba.substack.com
# creditnews.com
# credoaction.com
# crenews.com
# crescentavalleyweekly.com
# crestedbuttenews.com
# crestviewbulletin.com
# cricket.com.au
# cricketfever.org
# cricketweb.net
# cricxtasy.com
# criernewsroom.com
# crime-research.org
# crimethinc.com
# criminologyopen.com
# criminologystories.com
# crimrxiv.com
# crimsonquarry.com
# criticalhit.net
# critiqueecho.com
# crittendenpress.blogspot.com
# crn.in
# cronicaweb.com
# crookedtimber.org
# crooksandliars.com
# crookwellgazette.com.au
# crosscut.com
# crossingbroad.com
# crosstimbersgazette.com
# crozetgazette.com
# crozetseafood.com
# cruisecritic.com
# cruisefever.net
# cruisehive.com
# cruiseindustrynews.com
# cruiseradio.net
# cruiserepairs.com
# crusadernews.com
# cruxnow.com
# cryptoninjas.net
# cryptopolitan.com
# cryptopotato.com
# cryptovalleyjournal.com
# cs.astronomy.com
# csakenya.org
# csis.org
# csmonitor.com
# csnews.com
# csoonline.com
# cspinet.org
# cstoredecisions.com
# csu-cauldron.com
# csusmchronicle.com
# ctccusa.com
# ctmirror.org
# ctnewsjunkie.com
# ctpublic.org
# ctvnews.ca
# cuatower.com
# cubachronicle.com
# cubanet.org
# cubanews.acn.cu
# cubiclane.com
# cuencahighlife.com
# cuestonian.com
# cuindependent.com
# cultclassicsllc.toast.site
# cultmtl.com
# cultofmac.com
# culturaocio.com
# culture.org
# culturestudypod.substack.com
# curacao.nu
# curbed.com
# current-news.co.uk
# currentcites.org
# currentstarponsprings.com
# currentthing.substack.com
# cursdeguvernare.ro
# cutlefish.substack.com
# cuttingedgeinfo.com
# cvj.ch
# cw33.com
# cw39.com
# cxnetwork.com.au
# cyberciti.biz
# cybernews.com
# cyberscoop.com
# cybersectools.com
# cybersecurity360.it
# cybershack.com.au
# cyclicdefrost.com
# cyclingmagazine.ca
# cyclingnews.com
# cyclingweekly.com
# cynthanascoopsandtreats.online
# cynthiachung.substack.com
# cypriumnews.com
# cyprus-mail.com
# cyprusscene.com
# d-silence.com
# d1softballnews.com
# d2d-l.com
# daanishmahmood.substack.com
# daaz.com
# dabirdmmm.com
# dagblog.com
# daily.fattail.com.au
# daily49er.com
# dailyadvertiser.com.au
# dailyadvocate.com
# dailyblogging.com.au
# dailyblogs.com.au
# dailybulldog.com
# dailybusinessgroup.co.uk
# dailycaller.com
# dailycampus.com
# dailyclimate.org
# dailycollegian.com
# dailydot.com
# dailyexcelsior.com
# dailyfreepress.com
# dailyfulki.com
# dailyfx.com
# dailygame.net
# dailyguidenetwork.com
# dailyherald.com
# dailyhive.com
# dailyhornet.com
# dailyiowan.com
# dailyknicks.com
# dailykos.com
# dailyliberal.com.au
# dailymail.co.uk
# dailymaverick.co.za
# dailynewsfromaolf.substack.com
# dailynorseman.com
# dailynorthwestern.com
# dailyoilbulletin.com
# dailyorange.com
# dailypost.co.uk
# dailypost.ng
# dailyrecord.co.uk
# dailyridge.com
# dailysabah.com
# dailysignal.com
# dailysport.co.uk
# dailysquib.co.uk
# dailystar.co.uk
# dailythepatriot.com
# dailytidings.com
# dailytimes.com.pk
# dailytimesng.com
# dailytrib.com
# dailytrust.com
# dailyvoice.co.za
# dailyvoice.com
# dairyjoydrivein.com
# dairylandexpress.com
# dakila.rappler.com
# dakotanewsnow.com
# dakotawarcollege.com
# dalgazette.com
# dallas.culturemap.com
# dallascowboys.com
# dallasexaminer.com
# dallasmlkcenter.com
# dallasobserver.com
# dallast59.substack.com
# dallasvoice.com
# dallasweekly.com
# dalocalboy.toast.site
# danapointtimes.com
# dancehallmag.com
# dandenong.starcommunity.com.au
# daniel.haxx.se
# dannymorrison.com
# danq.me
# danspapers.com
# danvillesanramon.com
# danwoottonoutspoken.com
# dappered.com
# darkreading.com
# darkside.ru
# darrellricke.substack.com
# darrinbell.substack.com
# data-feminism.mitpress.mit.edu
# data.clarionledger.com
# data.lohud.com
# dataprotectionreport.com
# dataprovider.com
# datatuneconf.com
# dataweek.co.za
# davaotoday.com
# davekarpf.substack.com
# daventryexpress.co.uk
# davesholton.com
# davesipaq.com
# david-smith.org
# davidgosselin.substack.com
# davidlat.substack.com
# davidnixon.substack.com
# davidrovics.substack.com
# davidsonian.com
# davidstockmanscontracorner.com
# davidswanson.org
# davidwalsh.name
# davisphinneyfoundation.org
# davisvanguard.org
# dawgnation.com
# dawgpounddaily.com
# dawgsbynature.com
# dawgsports.com
# dawn.com
# daytimeconfidential.com
# dayton.com
# dayton.rivals.com
# daytondailynews.com
# dazeinfo.com
# dbaxps.blogspot.com
# dbtnews.com
# dc.eater.com
# dc2.crimrxiv.com
# dcnews.ro
# dcnewsnow.com
# dcnnmagazine.com
# dcspotlight.com
# dcthomson.co.uk
# dcvelocity.com
# ddn.com
# de.ign.com
# de.indymedia.org
# dead-frog.com
# deadlinenews.co.uk
# dealbreaker.com
# deanhenderson.substack.com
# debbielerman.substack.com
# debrajeansfl.com
# debrecensun.hu
# debugpoint.com
# debugpointnews.com
# debwan.com
# decanter.com
# decaturish.com
# decaturmagazine.com
# deccanchronicle.com
# deccanherald.com
# decensorednews.substack.com
# decodingeverything.com
# decotidien.com
# dee746.substack.com
# deeperblue.com
# deephouseamsterdam.com
# deepseacapacity.oceandiscoveryleague.org
# deeside.com
# defector.com
# defence-blog.com
# defence.pk
# defenceweb.co.za
# defendernetwork.com
# defenestrationmag.net
# defense-update.com
# defense.gov
# defensedaily.com
# defensenews.com
# defenseone.com
# defensereview.com
# defensescoop.com
# dekhnews.com
# delawarecurrents.org
# delawarepublic.org
# delfi.ee
# delfi.lt
# delfjuicebar.com
# delgazette.com
# deliziosobistro.com
# dellacoffee.com
# delmarvapublicmedia.org
# deltabusinessjournal.com
# deltanewsweb.com
# demerarawaves.com
# democracymanifest.substack.com
# demodirt.com
# demotix.com
# denikn.cz
# denisrancourt.substack.com
# denofgeek.com
# denver7.com
# denverbroncos.com
# denverite.com
# denversports.com
# denverstiffs.com
# depauliaonline.com
# depor.com
# depthperceptionbyll.substack.com
# derbyshirefrisco.com
# derbyshiretimes.co.uk
# derbytelegraph.co.uk
# derryjournal.com
# derstandard.at
# descrier.co.uk
# deseret.com
# desertusa.com
# deshdoot.com
# design-engineering.com
# design-reuse.com
# design.metropublisher.com
# designernews.co
# designjustice.mitpress.mit.edu
# designworldonline.com
# desirable-future.org
# despardes.com
# detroit.eater.com
# detroitbadboys.com
# detroitlions.com
# detroitsportsnation.com
# devdiscourse.com
# devdutt.com
# developer.apple.com
# developer.microsoft.com
# developer.nvidia.com
# developers.cloudflare.com
# developers.googleblog.com
# developers.slashdot.org
# devon-cornwall-film.co.uk
# devonlive.com
# devpolicy.org
# dewittmedia.com
# dewsburyreporter.co.uk
# dexerto.com
# dhacdo.net
# dhakatribune.com
# dhbend.com
# dialogue.earth
# diamondleague.com
# diario.mx
# diario1.com
# diariodeibiza.com
# diariodepuertorico.com
# diariodonordeste.verdesmares.com.br
# diariojudio.com
# diariolainfo.com
# diariolasamericas.com
# diariosigloxxi.com
# diasporamessenger.com
# dice.fm
# dicebreaker.com
# diefreiheitsliebe.de
# diez.hn
# diggers.news
# digi24.ro
# digialps.com
# digiday.com
# digimanie.cz
# digital-dev.thehill.com
# digitalcameraworld.com
# digitalcloset.mitpress.mit.edu
# digitalinspiration.com
# digitaljournal.com
# digitalmarketnews.com
# digitalmedianet.com
# digitalmediawire.com
# digitalmonkeygaming.com
# digitalnative.tech
# digitaloutput.net
# digitalsouls.com
# digitaltrades.com.au
# digitaltrends.com
# digitaltveurope.com
# dillonheraldonline.com
# dinkycreekcuriosities.com
# diocesehelena.org
# dioceseofkerry.ie
# dioceseofscranton.org
# dip.org.ua
# diplomat.so
# dipnpizza.com
# diptakirti.blogspot.com
# directmotocross.com
# directorsblog.nih.gov
# directv.com
# dirt.asla.org
# dirtbikemagazine.com
# dirtysouthsoccer.com
# disabilityvisibilityproject.com
# disantillos.com
# disconnect.blog
# discountstore1804.com
# discourseblog.com
# discovermagazine.com
# discovermni.com
# disinformationchronicle.substack.com
# dispatchlive.co.za
# dissidentvoice.org
# distractify.com
# districtfray.com
# divernet.com
# diverseeducation.com
# diymag.com
# diyphotography.net
# djadjawurrung.com.au
# dknetwork.draftkings.com
# dlmag.com
# dmagazine.com
# dmarge.com
# dmcityview.com
# dmcl.biz
# dmdavid.com
# dn.no
# dnaindia.com
# dnanews.com.pk
# dnerhaus.toast.site
# dnsspeedtest.online
# docmalik.substack.com
# docmaps.knowledgefutures.org
# docoflastresort.substack.com
# docs.dyte.io
# doctor.ndtv.com
# documentarity.mitpress.mit.edu
# dodbuzz.com
# dodofinance.com
# dogonews.com
# dogtrainingnearyou.online
# dohanews.co
# doingitlocal.com
# dolcemag.com
# dolphinpools.us
# dolphinstalk.com
# dominicagazette.com
# dominicanewsonline.com
# dominicanrepublicpost.com
# dominicantoday.com
# domlife.org
# doncasterfreepress.co.uk
# donklephant.com
# donmoynihan.substack.com
# donnemagazine.it
# donsurber.substack.com
# doodle.com
# doonschool.com
# doorlesscarp953.substack.com
# doriegreenspan.substack.com
# dorzeczy.pl
# dose.ca
# dossier.today
# dotesports.com
# doubleverify.com
# doughheadpizza.com
# douglas.gov.im
# douglasglover.substack.com
# douglasmagazine.com
# downeast.com
# downriversundaytimes.com
# downtowncellars.toast.site
# dpl003.substack.com
# dpreview.com
# dqchannels.com
# dqtjif.bitlydns.net
# draftmag.com
# dragcoverage.com
# dragillustrated.com
# draysbay.com
# drchristopherexley.substack.com
# drclarecraig.substack.com
# drdavidjspeicher.substack.com
# dresdenenterprise.com
# drevo.uaportal.com
# drgoddek.com
# drillingcontractor.org
# drinksint.com
# drive.com.au
# drivencarguide.co.nz
# drjacobnordangard.substack.com
# drlf.substack.com
# drmikeyeadon.substack.com
# droid-life.com
# dronedj.com
# dronenr.com.au
# drreidsheftall.substack.com
# drrimatruthreports.substack.com
# drsamanthaboardman.substack.com
# drsambailey.substack.com
# drtesslawrie.substack.com
# drtrozzi.news
# drtrozzi.substack.com
# drugfree.org
# drugtargetreview.com
# drydeadfish.co.uk
# dsnews.com
# dtnext.in
# dubaichronicle.com
# dublinlive.ie
# dujour.com
# duke.rivals.com
# dukebasketballreport.com
# dundeeonline.com
# dunyanews.tv
# duqsm.com
# dutchcaribbeannews.com
# dutchreview.com
# duurzaam-ondernemen.nl
# dv.is
# dvcinquirer.com
# dvidshub.net
# dw.com
# dwell.com
# dwell.com:443
# e-channelnews.com
# e-dirt.co.za
# e360.yale.edu
# eabbas.substack.com
# eagereyes.org
# eaglenews.ph
# eaglenewsonline.com
# earlychildhood.stanford.edu
# earlylearningnation.com
# earlyowlcafe.toast.site
# earnesthart.blogspot.com
# earning-edge.com
# earth.com
# earthsky.org
# eastafricanewspost.com
# eastasiaforum.org
# eastcoastdaily.in
# eastcoastrugsupply.com
# eastdevonnews.co.uk
# easterneronline.com
# easterneye.biz
# easternhockeyleague.org
# eastfieldnews.com
# eastgreenwichnews.com
# eastidahonews.com
# eastmojo.com
# eastsidefeed.com
# easttexasgoldengloves.com
# easttexasradio.com
# easttexasreview.com
# eastvillagemagazine.org
# eastwickpress.com
# eatatsilkandspice.com
# eatenbymissionaries.blogspot.com
# eater.com
# eatfullspeed.com
# eatparlour.com
# eatthis.com
# ebiketips.road.cc
# ebm-journal.org
# ebxnews.com
# ecb.europa.eu
# eccentrik.substack.com
# eccunion.com
# echonews.org.uk
# echoroukonline.com
# eciks.com
# eclipsemagazine.com
# ecmweb.com
# ecmwf.int
# ecoclimax.com
# ecommerceguide.com
# economictimes.indiatimes.com
# economist.com.na
# ecowas.int
# ecumenicalnews.com
# ecurrent.com
# ed.stanford.edu
# eddkimber.substack.com
# edenmagnet.com.au
# edexlive.com
# edgefieldadvertiser.com
# edgenews.co.za
# edgewood.news
# edgytim.forums.rivals.com
# edgytim.rivals.com
# edie.net
# edinburghlive.co.uk
# edinburghnews.scotsman.com
# edition.cnn.com
# editorial.rottentomatoes.com
# editorialedomani.it
# edmonton.ctvnews.ca
# edmunds.com
# edsurge.com
# edv1694.substack.com
# edwardsnotaryshop.com
# edweek.org
# eeb.org
# eeworldonline.com
# efanews.eu
# efe.com
# efficientplantmag.com
# efinancialcareers-canada.com
# efinancialcareers.co.uk
# efinancialcareers.co.za
# efinancialcareers.com
# efinancialcareers.com.au
# efinancialcareers.dk
# efinancialcareers.fi
# efinancialcareers.hk
# efinancialcareers.ie
# efinancialcareers.it
# efinancialcareers.jp
# efinancialcareers.nl
# efinancialcareers.se
# efl.fr
# efluxmedia.com
# efrat.substack.com
# egilcapital.com
# egophobia.ro
# egyptianstreets.com
# eialonline.org
# eindhovennews.com
# einnews.com
# einpresswire.com
# ejelynskitchen.com
# ejewishphilanthropy.com
# ejmagnier.com
# ejpress.org
# ekathimerini.com
# ekonominyheter.se
# elagavemexican.org
# elaviso.com
# elciudadano.com
# elconfidencialdigital.com
# eldiario.es
# eldiariodecaracas.net
# eldiariony.com
# eldonnews.org
# eldoradospringsmo.com
# eldric.substack.com
# eleanorkonik.com
# electrek.co
# electricliterature.com
# electronicintifada.net
# electronicpaymentsinternational.com
# electronics-cooling.com
# electronics.howstuffworks.com
# eleftheriaonline.gr
# eleftherostypos.gr
# elespectador.com
# eleutheranews.com
# elfagr.org
# elginreview.com
# elitedaily.com
# elitesportsny.com
# elizabethhart.substack.com
# elizabethnickson.substack.com
# elleeseymour.com
# elliottmiddleton.substack.com
# ellyshotdogs.com
# elnuevodia.com
# elsaiselsa.substack.com
# elsalvadorperspectives.com
# elsolmexicanrestaurant.com
# eluniversal.com.mx
# elvaq.com
# elynews.com
# elysian.press
# emagazine.com
# emailwire.com
# emarketer.com
# embedded.substack.com
# embeddedcomputing.com
# emerald.tv
# emergency-services.news
# emilyrnunn.substack.com
# emirates247.com
# emmagarland.substack.com
# emojisushipa.com
# empataco.com
# empireofthekop.com
# empireonline.com
# empiresportsmedia.com
# empirestatenews.net
# emtv.com.pg
# en.armradio.am
# en.cedarnews.net
# en.dailypakistan.com.pk
# en.developmentscout.com
# en.globes.co.il
# en.granma.cu
# en.haberler.com
# en.inform.kz
# en.interfax.com.ua
# en.irna.ir
# ...
# tomorrowsworldtoday.com
# tomryan.substack.com
# tomsguide.com
# tomshardware.com
# tomthefinder.com
# tomwalton.substack.com
# tonedeaf.thebrag.com
# toneglow.substack.com
# tonyknowles.com
# toofab.com
# tooheysbbq.com
# top40-charts.com
# topic.ie
# topick.hket.com
# topshotsshooting.com
# torchonline.com
# toronto.anglican.ca
# toronto.citynews.ca
# toronto.ctvnews.ca
# torontoguardian.com
# torontohistory.substack.com
# torotimes.com
# torrentfreak.com
# totalgaming.co.uk
# totalityofevidence.substack.com
# totalmotorcycle.com
# totalrl.com
# totaltele.com
# tourmag.com
# tovima.gr
# towleroad.com
# townhall.com
# townshipjournal.com
# tpr.org
# traackr.com
# trackalerts.com
# tracksideonline.com
# tractionlife.com
# tradedoubler.com
# tradewindsnews.com
# tradingpedia.com
# trafficc.com.au
# traktuell.at
# transcriberb.substack.com
# transferpricingnews.com
# translatingcuba.com
# transnational.live
# travel.india.com
# travel.nine.com.au
# travelagentcentral.com
# travelawaits.com
# travelbite.co.uk
# travelmag.co.uk
# travelwires.com
# travelwise.life
# trbusiness.com
# treeofwoe.substack.com
# treknews.net
# tremendoushumanity.substack.com
# trendingtopics.eu
# trendoceans.com
# trendystyle.com.hk
# trendzoom.com
# trevorklee.substack.com
# triad-city-beat.com
# triangledowntowner.com
# tribalchurch.org
# tribuna.us
# tribunademexico.com
# tribune.net.ph
# tribuneindia.com
# tribuneonlineng.com
# tridentnewspaper.com
# trillmag.com
# trinidadtribune.com
# trinitytripod.com
# triplem.com.au
# trishwood.substack.com
# tristantimes.com
# tristatehomepage.com
# trlgames.com
# trofire.com
# tropicalfete.com
# tropicanaboba.com
# tropicsofmeta.com
# troyhunt.com
# troymedia.com
# troymessenger.com
# trucknews.com
# truebluela.com
# truehoop.com
# trueshineautodetail.com
# trumatter.in
# trust-zine.de
# trustedreviews.com
# trusttheevidence.substack.com
# truth613.substack.com
# truthaddict.substack.com
# truthdig.com
# truthinit.com
# truthinmedia.com
# truthout.org
# truthsummit.substack.com
# tscra.org
# tsln.com
# tsn.ca
# tt.com
# ttrweekly.com
# tttapa.github.io
# tucoschild.substack.com
# tucsonweekly.com
# tudn1220.com
# tuko.co.ke
# tulsa.forums.rivals.com
# tulsa.rivals.com
# tulsatoday.com
# tumblerridgenews.com
# tunisiesoir.com
# tunnelingonline.com
# turan.az
# turfmagazine.com
# turfseer.substack.com
# turfshowtimes.com
# turkish-football.com
# turnto23.com
# turquoiseroof.org
# tv20detroit.com
# tvanswerman.com
# tvcnews.tv
# tvfanatic.com
# tvgrapevine.com
# tvguide.com
# tvinsider.com
# tvone.tv
# tvovermind.com
# tvseriesfinale.com
# tvtechnology.com
# tvw.org
# tvwise.co.uk
# tvyumuri.cu
# tweaktown.com
# twincities.eater.com
# twinfinite.net
# twinkietown.com
# twis.org
# twistedsifter.com
# twitchy.com
# twst.com
# twtd.co.uk
# twulasso.com
# txktoday.com
# tyburrswatchlist.substack.com
# tyht.cgixix.com
# tynmagazine.com
# tysuptowngrill.com
# u.today
# u2interference.com
# ualrpublicradio.org
# ubudcommunity.com
# ubuntushell.com
# ucanews.com
# ucbradio.com
# ucentralmedia.com
# ucf.forums.rivals.com
# ucf.rivals.com
# ucla.rivals.com
# ucmp.berkeley.edu
# ucsdguardian.org
# udn.com
# udreview.com
# uefa.com
# uga.forums.rivals.com
# uga.rivals.com
# uhnd.com
# uinterview.com
# uk.motor1.com
# ukhumanrightsblog.com
# uknip.co.uk
# ukrainefrontlines.com
# ukrainetoday.org
# ulladullatimes.com.au
# ulstertatler.com
# ultimateclassicrock.com
# ultimatemotorcycling.com
# ultiworld.com
# umamitrussville.com
# umdstatesman.com
# umobile.edu
# unbekoming.substack.com
# uncaptured.media
# unchartedterritories.tomaspueyo.com
# uncmirror.com
# uncut.co.uk
# undark.org
# underdogdynasty.com
# underhoodservice.com
# understandingai.org
# undertheradarmag.com
# unewsonline.com
# unfspinnaker.com
# unherd.com
# unidivers.fr
# unilad.com
# unionnewsdaily.com
# uniqode.com
# unisonalberta.com
# univercity.wisc.edu
# universe.byu.edu
# universetoday.com
# universetoday.fireside.fm
# universitychron.com
# universitystar.com
# unlock.org.uk
# unlockalberta.substack.com
# unosantafe.com.ar
# unpopularfront.news
# unrulyfigures.substack.com
# unser-mitteleuropa.com
# unterminated.com
# uoc.edu
# upday.com
# upi.com
# uploadvr.com
# upmatters.com
# upnorthmotorsports.bdnblogs.com
# upnorthnewswi.com
# uppermichiganssource.com
# upr.org
# upressonline.com
# uproxx.com
# upstatehouse.com
# upstreamonline.com
# uptownbbq.net
# uptowncollective.com
# uptownmessenger.com
# upworthy.com
# urbanacitizen.com
# urbanislandz.com
# urbanmilwaukee.com
# urdupoint.com
# urgentcomm.com
# urhobotoday.com
# ursinus.edu
# uruknet.org.uk
# us.blastingnews.com
# us.motorsport.com
# usa.philips.com
# usa.streetsblog.org
# usafricaonline.com
# usahockey.com
# usc.rivals.com
# uscho.com
# uscnpm.org
# useinsider.com
# usf.forums.rivals.com
# usf.rivals.com
# usfinancepost.com
# usgs.gov
# usmagazine.com
# usmedicine.com
# ussoccerplayers.com
# uswitch.com
# utah.rivals.com
# utdmercury.com
# utep.rivals.com
# uticaphoenix.net
# utsa.rivals.com
# uuworld.org
# uvureview.com
# uwdawgpound.com
# uwhealth.org
# uwimprint.ca
# uwpexponent.com
# uwrfvoice.com
# v100.fm
# va.gov
# vaca-ps.org
# vahalalmeat.com
# vaildaily.com
# valencianoticias.com
# vallartadaily.com
# vallartatoday.com
# valleyadvocate.com
# valleycentral.com
# valleyfencecompany.com
# valleyjournals.com
# valleynewslive.com
# valleyreporter.com
# valleytimes-news.com
# valuewalk.com
# valverdediario.es
# valverus.info
# vancouverisland.ctvnews.ca
# vanderbilt.forums.rivals.com
# vanderbilt.rivals.com
# vanguardngr.com
# vanquishthefoe.com
# varahiindiankitchen.com
# vaughantoday.ca
# vavel.com
# vbjusa.com
# vccircle.com
# veganricha.com
# vegas.eater.com
# vegashockeynow.com
# vegasmagazine.com
# vegconomist.com
# velomotion.net
# venturebeat.com
# venturesafrica.com
# verbit.ai
# verdenews.com
# verdict.co.uk
# verdict.justia.com
# vermontjournal.com
# vermontpublic.org
# versatilefenceco.com
# verticalmag.com
# vervemagazine.in
# veryofficialnews.substack.com
# vestaviavoice.com
# vesuviolive.it
# vet-magazin.com
# vexnews.com
# vg247.com
# vgchartz.com
# vheadline.com
# vicetv.com
# vicksburgpost.com
# vicnews.com
# vicparkpetition.substack.com
# victoriaarand.substack.com
# videobolt.net
# videogames.si.com
# viennatimes.com
# vietbao.vn
# vietnam.vnanet.vn
# vietnaminsider.vn
# vietnamnews.vn
# view.com.au
# viewfromthewing.com
# viewnews.com.au
# vifreepress.com
# vigilantfox.news
# vigourtimes.com
# villagegreennj.com
# villagelivingonline.com
# villagemagazine.ie
# villagenews.com
# villages-news.com
# villamercedes.info
# vincentsg.dev
# vindobona.org
# vinepair.com
# vino-joy.com
# vintagecomputing.com
# vintageguitar.com
# viral.media.mit.edu
# viralimmunologist.substack.com
# virgin.com
# virginia.rivals.com
# virginialiving.com
# virginiapreps.forums.rivals.com
# virginiapreps.rivals.com
# virginiastar.net
# virginiatech.forums.rivals.com
# virginiatech.rivals.com
# vision-hope.org
# visiontimes.com
# visir.is
# visitbuffaloniagara.com
# visitpwc.com
# vitalk9training.com
# vitalmx.com
# vittlesmagazine.com
# vivaelbirdos.com
# vkc.sh
# vlast.kz
# voanews.com
# voazimbabwe.com
# vocalo.org
# vocfm.co.za
# voguetaxservices.com
# voicendata.com
# voiceofoc.org
# voiceofsandiego.org
# voiceofsikkim.com
# voiceofvienna.org
# voices.ilo.org
# volanteonline.com
# volleyballmag.com
# voltairenet.org
# volts.wtf
# volumes.blog
# vooks.net
# voonze.com
# vox.com
# vox.gi
# voz.us
# vsparadiserestaurant.com
# vsuspectator.com
# vt-world.com
# vtskiandride.com
# vtsports.com
# vuemastery.com
# vuhoops.com
# vulture.com
# vvng.com
# wabi.tv
# wafb.com
# waff.com
# wagmtv.com
# waihekegulfnews.co.nz
# wakefieldexpress.co.uk
# wakeforest.rivals.com
# walb.com
# walesonline.co.uk
# wallpaper.com
# wallstreet-online.de
# wallstreetpit.com
# wallstreetwindow.com
# wamc.org
# wamcpodcasts.org
# wan-press.org
# wanderlustchloe.com
# wane.com
# wanhaber.com
# wantedinrome.com
# wantedonline.co.za
# warandpeas.com
# wargamer.com
# warm1013.com
# warm1069.com
# warontherocks.com
# warrandytediary.com.au
# warwickadvertiser.com
# warwickshire.gov.uk
# warwickshireworld.com
# washington.rivals.com
# washingtonblade.com
# washingtoncontinent.com
# washingtonexaminer.com
# washingtonhispanic.com
# washingtonian.com
# washingtoninformer.com
# washingtonjewishweek.com
# washingtonmonthly.com
# washjeff.edu
# waste-management-world.com
# watchdoguganda.com
# watchers.news
# watchesworld.com
# watchtheyard.com
# wate.com
# waterfrontpress.com
# waterfronttimes.com
# waterlandblog.com
# watermarkonline.com
# watertechonline.com
# watoday.com.au
# watson.ch
# wausaupilotandreview.com
# wave3.com
# wavemagazine.net
# wavy.com
# wawa-news.com
# waynebesen.com
# waynedalenews.com
# waynesworldhub.com
# waynetimes.com
# wayves.ca
# wbaa.org
# wbay.com
# wbckfm.com
# wbfj.fm
# wbfo.org
# wbjb.org
# wbko.com
# wbng.com
# wboc.com
# wboi.org
# wboy.com
# wbrs.org
# wbrz.com
# wbtv.com
# wbtw.com
# wbur.org
# wcax.com
# wcbi.com
# wccq.com
# wcel.nwaonline.com
# wchaustralia.substack.com
# wchbritishisles.substack.com
# wchsnetwork.com
# wcia.com
# wcpo.com
# wctv.tv
# wdac.com
# wdam.com
# wdbj7.com
# wdbo.com
# wdiy.org
# wdjx.com
# wdtn.com
# wdtv.com
# wduv.com
# weaintgotnohistory.sbnation.com
# wealthofgeeks.com
# wealthsimple.com
# wearegreenbay.com
# wearemitu.com
# wearethecity.com
# wearetheobserver.com
# wearetyrone.com
# weau.com
# web.sheffieldlive.org
# web2020.ffzg.unizg.hr
# web3.insidethegames.biz
# web4.insidethegames.biz
# web5.insidethegames.biz
# web6.insidethegames.biz
# webbikeworld.com
# webbrowsertools.com
# webfoundation.org
# webmd.com
# webohrid.com
# webpronews.com
# wect.com
# wedr.com
# weekendreading.net
# weekendsbbq.com
# weeklyblitz.net
# wegotthiscovered.com
# welcometheeagle.substack.com
# wellingtontimes.com.au
# weltjournal.de
# wemu.org
# weproject.media
# weraveyou.com
# wers.org
# wesa.fm
# wesleyanargus.com
# wesleyconover.com
# wessexscene.co.uk
# westbocanews.com
# westchesterfamily.com
# westendcommission.com
# westender.com.au
# westernadvocate.com.au
# westerndriver.com
# westernfrontonline.com
# westernhorseman.com
# westernjournal.com
# westernmassnews.com
# westernstandard.news
# westerntelegraph.co.uk
# westhartfordct.gov
# westlondonsport.com
# westmilfordmessenger.com
# westnipissing.com
# westofthei.com
# westseattleblog.com
# westsidetoday.com
# westtawakoniedc.com
# westviewnews.org
# westvirginia.rivals.com
# westword.com
# wethefree.substack.com
# weuponit.com
# wfae.org
# wfin.com
# wfirnews.com
# wfit.org
# wfjawwgpradio.com
# wfla.com
# wfls.com
# wflx.com
# wfsj.org
# wftv.com
# wfuogb.com
# wfwfzv.awsve.com
# wgaaradio.com
# wgclradio.com
# wgel.com
# wgem.com
# wgmd.com
# wgno.com
# wgnradio.com
# wgntv.com
# whatcar.com
# whatever.scalzi.com
# whathifi.com
# whats-on-netflix.com
# whatsgoodonline.co.uk
# whatsnew2day.com
# whatson.ae
# whatsonstage.com
# whatsthatyourecookingthea.substack.com
# whatsupcanada.substack.com
# whatsupnewp.com
# whatsupnewp.substack.com
# whattocook.substack.com
# whattowatch.com
# whatyoucando.substack.com
# whav.net
# whbc.com
# whci.online
# whdh.com
# whec.com
# whee.net
# wheon.com
# wherearethenumbers.substack.com
# wherepeteris.com
# whfp.com
# whio.com
# whiskyexperts.net
# whistlestopbarbecuellc.toast.site
# whiteplainscnr.com
# whitetoolong.net
# whmi.com
# whnt.com
# who13.com
# whoateallthepies.tv
# whodiedtoday.com
# whowhatwear.com
# whqr.org
# whsv.com
# whus.org
# whyevolutionistrue.com
# whythebookwins.com
# whyy.org
# wibc.com
# wibw.com
# wibx950.com
# wickcommunications.com
# wickedmike.substack.com
# wickedwingcoworcester-9oavehzx.toast.site
# wicnews.com
# wideopencountry.com
# wideopenspaces.com
# widerightnattylite.com
# wifr.com
# wigantoday.net
# wikifolio.com
# wikipedia20.mitpress.mit.edu
# wilcoxnewspapers.com
# wildchefmealprep.com
# wildchina.com
# wilderkingsdoodles.com
# wildfindsanddesigns.com
# williamdurand.fr
# williamlam.com
# williamsonsource.com
# wilmott.com
# wiltshirelive.co.uk
# wilx.com
# wimsradio.com
# windowscentral.com
# windowslatest.com
# windsor.ctvnews.ca
# windsorite.ca
# windycitygridiron.com
# windypundit.com
# wineeconomist.com
# wineloverspage.com
# winenews.it
# winetitles.com.au
# wingingitinmotown.com
# winknews.com
# winnipeg.ctvnews.ca
# winterwatch.net
# wionews.com
# wip.mitpress.mit.edu
# wired-gov.net
# wirelessandmobilenews.com
# wisconsin.edu
# wisconsin.forums.rivals.com
# wisconsin.rivals.com
# wisconsinreport.com
# wisconsinwatch.org
# wisdomofcrowds.live
# wise.com
# wisebread.com
# wishtv.com
# wistv.com
# witchsidetavern.com
# withthefirstpick.com
# witn.com
# wivb.com
# wiznation.com
# wjbf.com
# wjct.org
# wjcu.org
# wjhg.com
# wjhl.com
# wjjo.com
# wjnt.com
# wjol.com
# wjon.com
# wjts.tv
# wjtv.com
# wkar.org
# wkbn.com
# wkbw.com
# wkfr.com
# wkms.org
# wknofm.org
# wkrb13.com
# wkrg.com
# wkrn.com
# wku.rivals.com
# wkxi.com
# wkyt.com
# wkyufm.org
# wlbt.com
# wlip.com
# wlns.com
# wlns.incentrev.com
# wlox.com
# wlrn.org
# wmagazine.com
# wmar2news.com
# wmbfnews.com
# wmbriggs.com
# wmfe.org
# wmmo.com
# wmnf.org
# wmot.org
# wmse.org
# wmtv15news.com
# wmuk.org
# wnct.com
# wncw.org
# wnd.com
# wndu.com
# wnem.com
# wnewsj.com
# wng.org
# wnol.info
# wnyc.org
# wnycatholic.org
# wnycstudios.org
# wnyfamilymagazine.com
# woay.com
# wocmag.org
# wogx.com
# wokingnewsandmail.co.uk
# wokv.com
# wolbbaltimore.com
# wolfstreet.com
# womanandhome.com
# womenlovetech.com
# womenseconomicinstitute.com
# womensenews.org
# wonderchannel.it
# wonkette.com
# woodcarvingillustrated.com
# woodhouse76.com
# woodindustry.ca
# woodnstone820.substack.com
# woods-n-waternews.com
# woods.stanford.edu
# woodtv.com
# woodworkersjournal.com
# woofboomnews.com
# woolfwoolfmag.com
# wordinblack.com
# wordpress.com
# wordpress.org
# words.mattiasdesmet.org
# workers.org
# workingre.com
# worklife.news
# worksopguardian.co.uk
# workspace.google.com
# world-today-journal.com
# world-track.org
# world.einnews.com
# worldboxingnews.net
# worldcouncilforhealth.substack.com
# worldfootynews.com
# worldfuturecouncil.org
# worldisraelnews.com
# worldjournal.com
# worldofcruising.co.uk
# worldreportnow.com
# worldscreen.com
# worldsoccer.com
# worldsoccertalk.com
# worldsquash.org
# worldsurfleague.com
# worldtimes.co.jp
# worldtribune.com
# worldunitednews.blogspot.com
# wour.com
# wowhead.com
# wowktv.com
# wowo.com
# wowt.com
# wpcv.com
# wpdh.com
# wpri.com
# wpst.com
# wptf.com
# wptv.com
# wpvmfm.org
# wpxi.com
# wqbe.com
# wqcs.org
# wradio.com.co
# wrbh.org
# wrbl.com
# wrde.com
# wrdw.com
# wreg.com
# wrek.org
# wrestlingheadlines.com
# wrestlinginc.com
# wrestlingnewssource.com
# wrestlingnewsworld.com
# wrfalp.com
# wric.com
# wrightstownspirit.com
# writerstreasure.com
# writersweekly.com
# writinginwonderland.blogspot.com
# wrjc.com
# wrkf.org
# wrmf.com
# wrn.com
# wrp.org.uk
# wrtv.com
# wruf.com
# wruv.org
# wrvo.org
# wrvu.org
# wsav.com
# wsaw.com
# wsaz.com
# wsbradio.com
# wsbs.com
# wsbtv.com
# wsfa.com
# wsfltv.com
# wsfm.com.au
# wsgw.com
# wshu.org
# wskg.org
# wsls.com
# wsmv.com
# wsnews.org
# wsoctv.com
# wspa.com
# wsvn.com
# wtaj.com
# wtap.com
# wtatennis.com
# wtaw.com
# wtkr.com
# wtlcfm.com
# wtmj.com
# wtmx.com
# wtnh.com
# wtoc.com
# wtok.com
# wtop.com
# wtrf.com
# wtvm.com
# wtvr.com
# wtvy.com
# wtxl.com
# wuft.org
# wujimacha.com
# wunc.org
# wusf.org
# wuwf.org
# wuwm.com
# wvasfm.org
# wvia.org
# wvlt.tv
# wvnstv.com
# wvpe.org
# wvpress.org
# wvtf.org
# wvva.com
# wvxu.org
# wweek.com
# wwlp.com
# wwno.org
# wwnrradio.com
# wwos.nine.com.au
# wwoz.org
# www1.folha.uol.com.br
# www1.politicalbetting.com
# www2.cbn.com
# www2.cheatsheet.com
# www2.politicalbetting.com
# wwww.paristheatredirect.com
# wxpr.org
# wxxinews.org
# wxyz.com
# wyclif.substack.com
# wykop.pl
# wylienews.com
# wymt.com
# wyo4news.com
# wyofile.com
# wyomingnewsnow.tv
# wyomingpublicmedia.org
# wypr.org
# wyshradio.com
# wyso.org
# wysu.org
# wytv.com
# wzakcleveland.com
# x96.com
# xactlycorp.com
# xblafans.com
# xboxdynasty.de
# xda-developers.com
# xeniagazette.com
# xenoxnews.com
# xiaomiui.net
# xlr8r.com
# xpressmag.com.au
# xxlmag.com
# y100fm.com
# y107.com
# y95country.com
# yachtingmonthly.com
# yachtingworld.com
# yaconic.com
# yahoo.com
# yaledailynews.com
# yalibnan.com
# yandex.cloud
# yankodesign.com
# yanoticias.es
# yasstribune.com.au
# yated.com
# yayoiramen.com
# yello.substack.com
# yellowblog.com.au
# yellowleafpublishing.org
# yemenextra.net
# yen.com.gh
# yendidirestaurants.com
# yeniasya.com.tr
# yenisafak.com
# yesmagazine.org
# ynaija.com
# ynetnews.com
# yohaig.ng
# yolandapritamhari.substack.com
# yonkerstribune.com
# yorkpress.co.uk
# yorkshireeveningpost.co.uk
# yorkshirepost.co.uk
# yoteastudio.com
# youarecurrent.com
# youarehere.mitpress.mit.edu
# youknowigotsoul.com
# younewsng.com
# youngwitness.com.au
# yourappleupdate.substack.com
# yourbasin.com
# yourcentralvalley.com
# yourconcordtv.org
# yourdailyjournal.com
# yourerie.com
# yourgibraltartv.com
# yourlocalepidemiologist.substack.com
# yourmortgage.co.uk
# yourmortgage.com.au
# yourpickenscounty.com
# yourpockettherapist.substack.com
# yourstory.com
# yourtahoeguide.com
# yourtango.com
# yourvalley.net
# yovenice.com
# yovizag.com
# ypradio.org
# yro.slashdot.org
# ysnews.com
# yubanet.com
# yucommentator.com
# yucommentator.org
# zacks.com
# zambiainvest.com
# zambianewsnetwork.com
# zambianobserver.com
# zatznotfunny.com
# zawya.com
# zazoom.it
# zdnet.com
# zeenews.india.com
# zeibiz.com
# zeldman.com
# zeminonline.net
# zergwatch.com
# zero2turbo.com
# zerohedge.com
# zerotackle.com
# zerowastechef.com
# zeteo.com
# zeyzeygrill.com
# ziaruldevalcea.ro
# ziffdavis.com
# zifmstereo.co.zw
# zigzag.co.za
# zimbabweonlinenews.com
# zimbabwesituation.com
# zimtribune.com
# zmescience.com
# znetwork.org
# znewsservice.com
# zonazealots.com
# zoomagazine.it
# zoomd.com
# zumic.com
# zwnews.com
# zyzzyva.org
# zz.te.ua

# %%
# Dictionary of all publisher with 1500+ articles and the number of articles they have
import glob
import os
import polars as pl

def count_english_articles_by_publisher(folder_path: str):
    """
    1. For each .parquet file in `folder_path`, read lazily with Polars.
    2. Filter rows where language == 'en'.
    3. Group by 'publisher' and count how many English articles each appears.
    4. Accumulate counts into a global dictionary.
    5. Filter publishers with more than 1500 articles, sort them, and print the result.
    """
    parquet_files = glob.glob(os.path.join(folder_path, "*.parquet"))
    if not parquet_files:
        print(f"No Parquet files found in: {folder_path}")
        return

    counts_dict = {}

    for pq_file in parquet_files:
        print(f"Processing: {pq_file}")

        # Lazily scan the Parquet file
        lazy_df = pl.scan_parquet(pq_file)

        # Filter for rows where language == 'en', group by publisher, and count
        grouped_df = (
            lazy_df
            .filter(pl.col("language") == "en")
            .group_by("publisher")
            .agg(pl.count("publisher").alias("count"))
            .collect()  # Execute the lazy query
        )

        # Update counts in the dictionary
        for row in grouped_df.to_dicts():
            pub = row["publisher"]
            cnt = row["count"]
            counts_dict[pub] = counts_dict.get(pub, 0) + cnt

    # Filter out publishers with 1500 or fewer articles
    filtered_dict = {pub: cnt for pub, cnt in counts_dict.items() if cnt > 1500}

    if not filtered_dict:
        print("No publishers found with more than 1500 English articles.")
        return

    # Sort publishers by count of English articles (descending)
    sorted_counts = sorted(filtered_dict.items(), key=lambda x: x[1], reverse=True)

    # Convert sorted list back into a dictionary for ordered printing
    sorted_dict = dict(sorted_counts)

    print("\nPublishers with more than 1500 English articles sorted by article count (descending):")
    print(sorted_dict)
    return(sorted_dict)


# Set this to your folder path containing the Parquet files.
folder_path = r"C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024"  # Adjust path as needed.
dictionary = count_english_articles_by_publisher(folder_path)
# Out:
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0000.parquet
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0001.parquet
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0002.parquet
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0003.parquet
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0004.parquet
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0005.parquet
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0006.parquet
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0007.parquet
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0008.parquet
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0009.parquet
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0010.parquet
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0011.parquet
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0012.parquet
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0013.parquet
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0014.parquet
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0015.parquet
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0016.parquet
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0017.parquet
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0018.parquet
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0019.parquet
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0020.parquet
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0021.parquet
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0022.parquet
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0024.parquet
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0025.parquet
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0026.parquet
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0027.parquet
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0028.parquet
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0029.parquet
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0030.parquet
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0031.parquet
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0032.parquet
#
# Publishers with more than 1500 English articles sorted by article count (descending):
# {'bnnbreaking.com': 221938, 'dailymail.co.uk': 193599, 'menafn.com': 183793, 'sportskeeda.com': 158229, 'sports.yahoo.com': 108768, 'yahoo.com': 104867, 'timesofindia.indiatimes.com': 100280, 'lokmattimes.com': 97258, 'theenterpriseleader.com': 94926, 'wkrb13.com': 90516, 'etfdailynews.com': 89709, 'themarketsdaily.com': 85770, 'einpresswire.com': 84332, 'hindustantimes.com': 77636, 'tickerreport.com': 74211, 'cbssports.com': 69836, 'mirror.co.uk': 66139, 'livemint.com': 65243, 'news.yahoo.com': 64684, 'thehindu.com': 60483, 'nasdaq.com': 59917, 'express.co.uk': 58398, 'prnewswire.com': 57211, 'latestly.com': 53116, 'economictimes.indiatimes.com': 52973, 'pledgetimes.com': 51972, 'gurufocus.com': 50734, 'americanbankingnews.com': 50417, 'devdiscourse.com': 45583, 'cbsnews.com': 44200, 'pinkvilla.com': 42843, 'si.com': 41981, 'exbulletin.com': 41636, 'forbes.com': 41495, 'republicworld.com': 41141, 'newindianexpress.com': 40230, 'globenewswire.com': 38467, 'newsdrum.in': 38290, 'freepressjournal.in': 37202, 'independent.co.uk': 36282, 'zawya.com': 35208, 'ndtv.com': 33961, 'thewest.com.au': 33589, 'finanznachrichten.de': 33293, 'business-standard.com': 32724, 'com-unik.info': 31552, 'finance.yahoo.com': 30302, 'urdupoint.com': 29595, 'ca.news.yahoo.com': 28310, 'dailystar.co.uk': 27886, 'ajc.com': 27656, 'clutchpoints.com': 27120, 'dailyrecord.co.uk': 26494, 'birminghammail.co.uk': 26056, 'metro.co.uk': 25741, 'nzherald.co.nz': 25685, 'telegraph.co.uk': 25499, 'iol.co.za': 24541, 'dvidshub.net': 23642, 'manchestereveningnews.co.uk': 23295, 'mondaq.com:443': 22980, 'foxnews.com': 22766, 'perthnow.com.au': 21744, 'broadwayworld.com': 21613, 'dailypost.ng': 21499, 'bnnbloomberg.ca': 21496, 'nation.com.pk': 21172, 'outlookindia.com': 21006, 'thedailystar.net': 20037, 'thesportsrush.com': 19081, 'indiatvnews.com': 18821, 'malaymail.com': 18811, 'dtnext.in': 18051, 'liverpoolecho.co.uk': 17675, 'thenationonlineng.net': 17406, 'deccanherald.com': 17387, 'forextv.com': 17283, 'kstp.com': 17258, 'brecorder.com': 16870, 'brighteon.com': 16694, 'globalnews.ca': 16648, 'allafrica.com': 16417, 'legit.ng': 16393, 'en.inform.kz': 16304, 'fansided.com': 16118, 'the-express.com': 16093, 'sportingnews.com': 15778, 'tribune.net.ph': 15743, 'millenniumpost.in': 15311, 'businessinsider.com': 15192, 'newsable.asianetnews.com': 14751, 'comicbook.com': 14410, 'walesonline.co.uk': 14394, 'goal.com': 14300, 'teamtalk.com': 14299, 'khaleejtimes.com': 14242, 'etvbharat.com': 14054, 'dotesports.com': 13913, 'jpost.com': 13870, 'heavy.com': 13772, 'theglobeandmail.com': 13759, 'irishtimes.com': 13745, 'sentinelassam.com': 13612, 'shawlocal.com': 13338, 'shropshirestar.com': 13274, 'breitbart.com': 13259, 'naijanews.com': 13064, 'thehindubusinessline.com': 13038, 'expressandstar.com': 12971, 'irishmirror.ie': 12951, 'benzinga.com': 12918, 'ca.sports.yahoo.com': 12824, 'dexerto.com': 12746, 'prweb.com': 12699, 'zeenews.india.com': 12630, 'siasat.com': 12498, 'ok.co.uk': 12373, 'telanganatoday.com': 12350, 'abc.net.au': 12293, 'reporter.am': 12144, 'chroniclelive.co.uk': 12133, 'deccanchronicle.com': 12036, 'pressandjournal.co.uk': 12021, 'newsbytesapp.com': 11880, 'thecourier.co.uk': 11863, 'wtop.com': 11761, 'castanet.net': 11746, 'tuko.co.ke': 11652, 'seekingalpha.com': 11628, 'wionews.com': 11606, 'hotnewhiphop.com': 11447, 'adomonline.com': 11397, 'collider.com': 11382, 'newtelegraphng.com': 11360, 'krdo.com': 11213, 'thenews.com.pk': 11166, 'en.people.cn': 11136, 'thequint.com': 11117, 'dnaindia.com': 11070, 'sussexexpress.co.uk': 11057, 'axios.com': 10997, 'scoop.co.nz': 10984, 'givemesport.com': 10971, 'latimes.com': 10739, 'tribuneindia.com': 10703, 'sunstar.com.ph': 10585, 'krone.at': 10505, 'kesq.com': 10422, 'inews.co.uk': 10394, 'citizen.co.za': 10284, 'newsmax.com': 10165, 'usmagazine.com': 10123, 'mobile.ghanaweb.com': 10111, 'indiatimes.com': 10069, 'ndtvprofit.com': 10026, 'hellomagazine.com': 9913, 'm.startribune.com': 9887, 'briefly.co.za':  ...

# %% [markdown]
# We manually chose news sources we thought were valuable to analyze, based on the country of origin, reputation and the activity of the newspaper.

# %%
publishers = ["abcactionnews.com", "abcnews.go.com", "africanews.com", "aljazeera.com", "azernews.az", "bnnbloomberg.ca", "bnnbreaking.com", "bostonglobe.com", "ca.news.yahoo.com", "cambridge-news.co.uk", "cbc.ca", "cbsnews.com", "chicago.suntimes.com", "chicagotribune.com", "cnbc.com", "cnn.com", "cyprus-mail.com", "dailymail.co.uk", "dailypost.co.uk", "dailysabah.com", "dailystar.co.uk", "dw.com", "edinburghlive.co.uk", "eurasiareview.com", "euronews.com", "forbes.com", "foxnews.com", "gazettelive.co.uk", "heraldscotland.com", "hindustantimes.com", "huffingtonpost.co.uk", "huffpost.com", "hurriyetdailynews.com", "independent.co.uk", "india.com", "indiatimes.com", "inews.co.uk", "irishmirror.ie", "irishtimes.com", "israelnationalnews.com", "japannews.yomiuri.co.jp", "japantimes.co.jp", "jewishpress.com", "jpost.com", "kyivindependent.com", "kyivpost.com", "nbcnews.com", "newsday.com", "northernirelandworld.com", "northumberlandgazette.co.uk", "nottinghampost.com", "npr.org", "ntv.ca", "nysun.com", "nzherald.co.nz", "palestinechronicle.com", "politico.eu", "pressandjournal.co.uk", "pressherald.com", "romania-insider.com", "sfstandard.com", "sputnikglobe.com", "standard.net.au", "telegraph.co.uk", "the-independent.com", "thedailystar.net", "thefederal.com", "theglobeandmail.com", "thehindu.com", "thesouthafrican.com", "thestar.co.uk", "thestatesman.com", "thesun.my", "theweek.com", "time.com", "timeslive.co.za", "timesofindia.indiatimes.com", "toronto.citynews.ca", "tribuneindia.com", "turan.az", "yahoo.com", "themoscowtimes.com", "globalnews.ca","syrianobserver.com","tass.com","rt.com"]

for key, value in sorted(dictionary.items(), key=lambda x: x[1], reverse=True):
    if key in publishers:
        print(key, value)
# Out:
# bnnbreaking.com 221938
# dailymail.co.uk 193599
# yahoo.com 104867
# timesofindia.indiatimes.com 100280
# hindustantimes.com 77636
# thehindu.com 60483
# cbsnews.com 44200
# forbes.com 41495
# independent.co.uk 36282
# ca.news.yahoo.com 28310
# dailystar.co.uk 27886
# nzherald.co.nz 25685
# telegraph.co.uk 25499
# foxnews.com 22766
# bnnbloomberg.ca 21496
# thedailystar.net 20037
# globalnews.ca 16648
# jpost.com 13870
# theglobeandmail.com 13759
# irishtimes.com 13745
# irishmirror.ie 12951
# pressandjournal.co.uk 12021
# tribuneindia.com 10703
# inews.co.uk 10394
# indiatimes.com 10069
# thestatesman.com 9764
# nottinghampost.com 9171
# abcnews.go.com 8643
# india.com 8486
# israelnationalnews.com 7763
# toronto.citynews.ca 7645
# bostonglobe.com 7353
# tass.com 7218
# pressherald.com 7201
# timeslive.co.za 7170
# cyprus-mail.com 6799
# thestar.co.uk 6782
# euronews.com 6569
# rt.com 6560
# aljazeera.com 6384
# sputnikglobe.com 6115
# kyivindependent.com 6098
# azernews.az 5730
# chicago.suntimes.com 5704
# nbcnews.com 5664
# dailysabah.com 5655
# heraldscotland.com 5561
# huffpost.com 5285
# japannews.yomiuri.co.jp 5278
# thefederal.com 5189
# edinburghlive.co.uk 4764
# cnn.com 4679
# northernirelandworld.com 4488
# japantimes.co.jp 4376
# gazettelive.co.uk 4274
# cbc.ca 4130
# thesun.my 3917
# newsday.com 3837
# eurasiareview.com 3600
# hurriyetdailynews.com 3464
# thesouthafrican.com 3450
# jewishpress.com 3373
# abcactionnews.com 3312
# nysun.com 3269
# dw.com 3263
# huffingtonpost.co.uk 3242
# time.com 3233
# standard.net.au 3010
# politico.eu 2951
# dailypost.co.uk 2724
# northumberlandgazette.co.uk 2710
# cambridge-news.co.uk 2701
# kyivpost.com 2647
# npr.org 2466
# theweek.com 2441
# cnbc.com 2284
# ntv.ca 2233
# the-independent.com 2004
# africanews.com 1899
# turan.az 1898
# chicagotribune.com 1868
# palestinechronicle.com 1867
# romania-insider.com 1857
# sfstandard.com 1635

# %%
import io
import glob
import os
import polars as pl

def selected_pubs_to_csv(folder_path: str, publishers: list, csv_filepath: str = "2024.csv"):
    parquet_files = glob.glob(os.path.join(folder_path, "*.parquet"))
    if not parquet_files:
        print(f"No Parquet files found in: {folder_path}")
        return None  # Return None if no files found

    for pq_file in parquet_files:
        print(f"Processing: {pq_file}")

        # Lazily scan the Parquet file
        lazy_df = pl.scan_parquet(pq_file)

        # Filter rows where language == 'en' and publisher is in the publishers list
        filtered_lazy_df = (
            lazy_df
            .filter((pl.col("language") == "en") & pl.col("publisher").is_in(publishers))
        )

        # Collect the filtered lazy DataFrame into a real DataFrame
        df = filtered_lazy_df.collect()


        # Check if file exists
        if not os.path.exists(csv_filepath):
            # If it doesn't exist, create it with headers
            df.write_csv(csv_filepath)
            print(f"File {pq_file} created at: {csv_filepath}")
        else:
            # 1) Write CSV into an in-memory buffer (includes header by default)
            buffer = io.StringIO()
            df.write_csv(buffer)
    
            # 2) Get full CSV text
            csv_str = buffer.getvalue()
    
            # 3) Strip off the first line (the header row)
            lines = csv_str.split('\n')
            # If the CSV isn’t empty, drop the first line.
            # Also be cautious about trailing newlines
            data_only = "\n".join(lines[1:]).strip('\n')
    
            # 4) Append data rows to the existing file
            with open(csv_filepath, 'a', encoding='utf-8') as f:
                # Optionally ensure a newline if the file doesn’t already end with one
                # You might want to check the last character in the file, 
                # but typically adding a newline is enough:
                f.write('\n' + data_only)

        print(f"Appended {pq_file} to existing file at: {csv_filepath}")
            
selected_pubs_to_csv(r'C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024', publishers, "2024.csv")
# Out:
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0000.parquet
# File C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0000.parquet created at: 2024.csv
# Appended C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0000.parquet to existing file at: 2024.csv
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0001.parquet
# Appended C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0001.parquet to existing file at: 2024.csv
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0002.parquet
# Appended C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0002.parquet to existing file at: 2024.csv
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0003.parquet
# Appended C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0003.parquet to existing file at: 2024.csv
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0004.parquet
# Appended C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0004.parquet to existing file at: 2024.csv
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0005.parquet
# Appended C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0005.parquet to existing file at: 2024.csv
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0006.parquet
# Appended C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0006.parquet to existing file at: 2024.csv
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0007.parquet
# Appended C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0007.parquet to existing file at: 2024.csv
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0008.parquet
# Appended C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0008.parquet to existing file at: 2024.csv
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0009.parquet
# Appended C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0009.parquet to existing file at: 2024.csv
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0010.parquet
# Appended C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0010.parquet to existing file at: 2024.csv
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0011.parquet
# Appended C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0011.parquet to existing file at: 2024.csv
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0012.parquet
# Appended C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0012.parquet to existing file at: 2024.csv
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0013.parquet
# Appended C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0013.parquet to existing file at: 2024.csv
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0014.parquet
# Appended C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0014.parquet to existing file at: 2024.csv
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0015.parquet
# Appended C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0015.parquet to existing file at: 2024.csv
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0016.parquet
# Appended C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0016.parquet to existing file at: 2024.csv
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0017.parquet
# Appended C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0017.parquet to existing file at: 2024.csv
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0018.parquet
# Appended C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0018.parquet to existing file at: 2024.csv
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0019.parquet
# Appended C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0019.parquet to existing file at: 2024.csv
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0020.parquet
# Appended C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0020.parquet to existing file at: 2024.csv
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0021.parquet
# Appended C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0021.parquet to existing file at: 2024.csv
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0022.parquet
# Appended C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0022.parquet to existing file at: 2024.csv
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0024.parquet
# Appended C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0024.parquet to existing file at: 2024.csv
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0025.parquet
# Appended C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0025.parquet to existing file at: 2024.csv
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0026.parquet
# Appended C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0026.parquet to existing file at: 2024.csv
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0027.parquet
# Appended C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0027.parquet to existing file at: 2024.csv
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0028.parquet
# Appended C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0028.parquet to existing file at: 2024.csv
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0029.parquet
# Appended C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0029.parquet to existing file at: 2024.csv
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0030.parquet
# Appended C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0030.parquet to existing file at: 2024.csv
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0031.parquet
# Appended C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0031.parquet to existing file at: 2024.csv
# Processing: C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0032.parquet
# Appended C:\Users\Admin\PycharmProjects\AI-Projects\CC_news\2024\2024_0032.parquet to existing file at: 2024.csv

# %%
# 1. Lazily read the CSV file
lazy_df = pl.scan_csv("2024.csv")

# 2. Group by the "publisher" column and count
counts_lazy = (
    lazy_df
    .group_by("publisher")
    .agg(pl.count())  # or .agg(pl.col("*").count()) to count rows
    .sort("count", descending=True)
)

# 3. Execute the lazy plan (collect) to get the result
counts_df = counts_lazy.collect()

# 4. Print or inspect the resulting DataFrame
pl.Config.set_tbl_rows(100_000)
print(counts_df)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5036\3597756387.py:8: DeprecationWarning: `pl.count()` is deprecated. Please use `pl.len()` instead.
#   .agg(pl.count())  # or .agg(pl.col("*").count()) to count rows
# shape: (87, 2)
# ┌─────────────────────────────┬────────┐
# │ publisher                   ┆ count  │
# │ ---                         ┆ ---    │
# │ str                         ┆ u32    │
# ╞═════════════════════════════╪════════╡
# │ bnnbreaking.com             ┆ 221938 │
# │ dailymail.co.uk             ┆ 193599 │
# │ yahoo.com                   ┆ 104867 │
# │ timesofindia.indiatimes.com ┆ 100280 │
# │ hindustantimes.com          ┆ 77636  │
# │ thehindu.com                ┆ 60483  │
# │ cbsnews.com                 ┆ 44200  │
# │ forbes.com                  ┆ 41495  │
# │ independent.co.uk           ┆ 36282  │
# │ ca.news.yahoo.com           ┆ 28310  │
# │ dailystar.co.uk             ┆ 27886  │
# │ nzherald.co.nz              ┆ 25685  │
# │ telegraph.co.uk             ┆ 25499  │
# │ foxnews.com                 ┆ 22766  │
# │ bnnbloomberg.ca             ┆ 21496  │
# │ thedailystar.net            ┆ 20037  │
# │ globalnews.ca               ┆ 16648  │
# │ jpost.com                   ┆ 13870  │
# │ theglobeandmail.com         ┆ 13759  │
# │ irishtimes.com              ┆ 13745  │
# │ irishmirror.ie              ┆ 12951  │
# │ pressandjournal.co.uk       ┆ 12021  │
# │ tribuneindia.com            ┆ 10703  │
# │ inews.co.uk                 ┆ 10394  │
# │ indiatimes.com              ┆ 10069  │
# │ thestatesman.com            ┆ 9764   │
# │ nottinghampost.com          ┆ 9171   │
# │ abcnews.go.com              ┆ 8643   │
# │ india.com                   ┆ 8486   │
# │ israelnationalnews.com      ┆ 7763   │
# │ toronto.citynews.ca         ┆ 7645   │
# │ bostonglobe.com             ┆ 7353   │
# │ tass.com                    ┆ 7218   │
# │ pressherald.com             ┆ 7201   │
# │ timeslive.co.za             ┆ 7170   │
# │ cyprus-mail.com             ┆ 6799   │
# │ thestar.co.uk               ┆ 6782   │
# │ euronews.com                ┆ 6569   │
# │ rt.com                      ┆ 6560   │
# │ aljazeera.com               ┆ 6384   │
# │ sputnikglobe.com            ┆ 6115   │
# │ kyivindependent.com         ┆ 6098   │
# │ azernews.az                 ┆ 5730   │
# │ chicago.suntimes.com        ┆ 5704   │
# │ nbcnews.com                 ┆ 5664   │
# │ dailysabah.com              ┆ 5655   │
# │ heraldscotland.com          ┆ 5561   │
# │ huffpost.com                ┆ 5285   │
# │ japannews.yomiuri.co.jp     ┆ 5278   │
# │ thefederal.com              ┆ 5189   │
# │ edinburghlive.co.uk         ┆ 4764   │
# │ cnn.com                     ┆ 4679   │
# │ northernirelandworld.com    ┆ 4488   │
# │ japantimes.co.jp            ┆ 4376   │
# │ gazettelive.co.uk           ┆ 4274   │
# │ cbc.ca                      ┆ 4130   │
# │ thesun.my                   ┆ 3917   │
# │ newsday.com                 ┆ 3837   │
# │ eurasiareview.com           ┆ 3600   │
# │ hurriyetdailynews.com       ┆ 3464   │
# │ thesouthafrican.com         ┆ 3450   │
# │ jewishpress.com             ┆ 3373   │
# │ abcactionnews.com           ┆ 3312   │
# │ nysun.com                   ┆ 3269   │
# │ dw.com                      ┆ 3263   │
# │ huffingtonpost.co.uk        ┆ 3242   │
# │ time.com                    ┆ 3233   │
# │ standard.net.au             ┆ 3010   │
# │ politico.eu                 ┆ 2951   │
# │ dailypost.co.uk             ┆ 2724   │
# │ northumberlandgazette.co.uk ┆ 2710   │
# │ cambridge-news.co.uk        ┆ 2701   │
# │ kyivpost.com                ┆ 2647   │
# │ npr.org                     ┆ 2466   │
# │ theweek.com                 ┆ 2441   │
# │ cnbc.com                    ┆ 2284   │
# │ ntv.ca                      ┆ 2233   │
# │ the-independent.com         ┆ 2004   │
# │ africanews.com              ┆ 1899   │
# │ turan.az                    ┆ 1898   │
# │ chicagotribune.com          ┆ 1868   │
# │ palestinechronicle.com      ┆ 1867   │
# │ romania-insider.com         ┆ 1857   │
# │ sfstandard.com              ┆ 1635   │
# │ themoscowtimes.com          ┆ 1384   │
# │ syrianobserver.com          ┆ 652    │
# │ null                        ┆ 1      │
# └─────────────────────────────┴────────┘

# %%
lst = pl.Series(counts_df.select('publisher')).to_list()
print(lst)
# Out:
# ['bnnbreaking.com', 'dailymail.co.uk', 'yahoo.com', 'timesofindia.indiatimes.com', 'hindustantimes.com', 'thehindu.com', 'cbsnews.com', 'forbes.com', 'independent.co.uk', 'ca.news.yahoo.com', 'dailystar.co.uk', 'nzherald.co.nz', 'telegraph.co.uk', 'foxnews.com', 'bnnbloomberg.ca', 'thedailystar.net', 'globalnews.ca', 'jpost.com', 'theglobeandmail.com', 'irishtimes.com', 'irishmirror.ie', 'pressandjournal.co.uk', 'tribuneindia.com', 'inews.co.uk', 'indiatimes.com', 'thestatesman.com', 'nottinghampost.com', 'abcnews.go.com', 'india.com', 'israelnationalnews.com', 'toronto.citynews.ca', 'bostonglobe.com', 'tass.com', 'pressherald.com', 'timeslive.co.za', 'cyprus-mail.com', 'thestar.co.uk', 'euronews.com', 'rt.com', 'aljazeera.com', 'sputnikglobe.com', 'kyivindependent.com', 'azernews.az', 'chicago.suntimes.com', 'nbcnews.com', 'dailysabah.com', 'heraldscotland.com', 'huffpost.com', 'japannews.yomiuri.co.jp', 'thefederal.com', 'edinburghlive.co.uk', 'cnn.com', 'northernirelandworld.com', 'japantimes.co.jp', 'gazettelive.co.uk', 'cbc.ca', 'thesun.my', 'newsday.com', 'eurasiareview.com', 'hurriyetdailynews.com', 'thesouthafrican.com', 'jewishpress.com', 'abcactionnews.com', 'nysun.com', 'dw.com', 'huffingtonpost.co.uk', 'time.com', 'standard.net.au', 'politico.eu', 'dailypost.co.uk', 'northumberlandgazette.co.uk', 'cambridge-news.co.uk', 'kyivpost.com', 'npr.org', 'theweek.com', 'cnbc.com', 'ntv.ca', 'the-independent.com', 'africanews.com', 'turan.az', 'chicagotribune.com', 'palestinechronicle.com', 'romania-insider.com', 'sfstandard.com', 'themoscowtimes.com', 'syrianobserver.com', None]

# %%
newspaper_locations = {
    "bnnbreaking.com": "AI generated news",
    "dailymail.co.uk": "United Kingdom",
    "yahoo.com": "United States (global services)",
    "timesofindia.indiatimes.com": "India",
    "hindustantimes.com": "India",
    "thehindu.com": "India",
    "cbsnews.com": "United States",
    "forbes.com": "United States",
    "independent.co.uk": "United Kingdom",
    "ca.news.yahoo.com": "Canada",
    "dailystar.co.uk": "United Kingdom",
    "nzherald.co.nz": "New Zealand",
    "telegraph.co.uk": "United Kingdom",
    "foxnews.com": "United States",
    "bnnbloomberg.ca": "Canada",
    "thedailystar.net": "Bangladesh",
    "globalnews.ca": "Canada",
    "jpost.com": "Israel",
    "theglobeandmail.com": "Canada",
    "irishtimes.com": "Ireland",
    "irishmirror.ie": "Ireland",
    "pressandjournal.co.uk": "United Kingdom (Aberdeen, Scotland)",
    "tribuneindia.com": "India",
    "inews.co.uk": "United Kingdom",
    "indiatimes.com": "India",
    "thestatesman.com": "India",
    "nottinghampost.com": "United Kingdom (Nottingham, England)",
    "abcnews.go.com": "United States",
    "india.com": "India",
    "israelnationalnews.com": "Israel",
    "toronto.citynews.ca": "Canada",
    "bostonglobe.com": "United States (Boston, Massachusetts)",
    "tass.com": "Russia (state news agency)",
    "pressherald.com": "United States (Portland, Maine)",
    "timeslive.co.za": "South Africa",
    "cyprus-mail.com": "Cyprus",
    "thestar.co.uk": "United Kingdom (Sheffield)",
    "euronews.com": "France (Pan-European)",
    "rt.com": "Russia (state-funded)",
    "aljazeera.com": "Qatar (international focus)",
    "sputnikglobe.com": "Russia (state-affiliated)",
    "kyivindependent.com": "Ukraine",
    "azernews.az": "Azerbaijan",
    "chicago.suntimes.com": "United States (Chicago, Illinois)",
    "nbcnews.com": "United States",
    "dailysabah.com": "Turkey",
    "heraldscotland.com": "United Kingdom (Scotland)",
    "huffpost.com": "United States (global editions)",
    "japannews.yomiuri.co.jp": "Japan",
    "thefederal.com": "India",
    "edinburghlive.co.uk": "United Kingdom (Edinburgh, Scotland)",
    "cnn.com": "United States",
    "northernirelandworld.com": "Northern Ireland (UK)",
    "japantimes.co.jp": "Japan",
    "gazettelive.co.uk": "United Kingdom (Teesside, England)",
    "cbc.ca": "Canada",
    "thesun.my": "Malaysia",
    "newsday.com": "United States (Long Island, New York)",
    "eurasiareview.com": "Global (Online publication)",
    "hurriyetdailynews.com": "Turkey",
    "thesouthafrican.com": "South Africa",
    "jewishpress.com": "United States (New York)",
    "abcactionnews.com": "United States (Tampa, Florida)",
    "nysun.com": "United States (New York)",
    "dw.com": "Germany",
    "huffingtonpost.co.uk": "United Kingdom",
    "time.com": "United States",
    "standard.net.au": "Australia",
    "politico.eu": "Belgium (European edition of Politico)",
    "dailypost.co.uk": "United Kingdom (Wales)",
    "northumberlandgazette.co.uk": "United Kingdom (Northumberland, England)",
    "cambridge-news.co.uk": "United Kingdom (Cambridge)",
    "kyivpost.com": "Ukraine",
    "npr.org": "United States",
    "theweek.com": "United States",
    "cnbc.com": "United States",
    "ntv.ca": "Canada (Newfoundland)",
    "the-independent.com": "United States (Grand Island, Nebraska)",
    "africanews.com": "Pan-African (headquartered in Congo-Brazzaville)",
    "turan.az": "Azerbaijan",
    "chicagotribune.com": "United States (Chicago, Illinois)",
    "palestinechronicle.com": "Focus on Palestine (editorial offices often in North America)",
    "romania-insider.com": "Romania",
    "sfstandard.com": "United States (San Francisco, California)",
    "themoscowtimes.com": "Russia/Europe (historically Russia-based)",
    "syrianobserver.com": "Focus on Syria (often run by international or exiled groups)"
    # "None" is omitted as it doesn't map to a real outlet
}
newspaper_countries = {
    "bnnbreaking.com": "AI generated news",   # Keeping as-is from original data
    "dailymail.co.uk": "England",
    "yahoo.com": "United States",
    "timesofindia.indiatimes.com": "India",
    "hindustantimes.com": "India",
    "thehindu.com": "India",
    "cbsnews.com": "United States",
    "forbes.com": "United States",
    "independent.co.uk": "England",
    "ca.news.yahoo.com": "Canada",
    "dailystar.co.uk": "England",
    "nzherald.co.nz": "New Zealand",
    "telegraph.co.uk": "England",
    "foxnews.com": "United States",
    "bnnbloomberg.ca": "Canada",
    "thedailystar.net": "Bangladesh",
    "globalnews.ca": "Canada",
    "jpost.com": "Israel",
    "theglobeandmail.com": "Canada",
    "irishtimes.com": "Ireland",
    "irishmirror.ie": "Ireland",
    "pressandjournal.co.uk": "Scotland",
    "tribuneindia.com": "India",
    "inews.co.uk": "England",
    "indiatimes.com": "India",
    "thestatesman.com": "India",
    "nottinghampost.com": "England",
    "abcnews.go.com": "United States",
    "india.com": "India",
    "israelnationalnews.com": "Israel",
    "toronto.citynews.ca": "Canada",
    "bostonglobe.com": "United States",
    "tass.com": "Russia",
    "pressherald.com": "United States",
    "timeslive.co.za": "South Africa",
    "cyprus-mail.com": "Cyprus",
    "thestar.co.uk": "England",
    "euronews.com": "France",
    "rt.com": "Russia",
    "aljazeera.com": "Qatar",
    "sputnikglobe.com": "Russia",
    "kyivindependent.com": "Ukraine",
    "azernews.az": "Azerbaijan",
    "chicago.suntimes.com": "United States",
    "nbcnews.com": "United States",
    "dailysabah.com": "Turkey",
    "heraldscotland.com": "Scotland",
    "huffpost.com": "United States",
    "japannews.yomiuri.co.jp": "Japan",
    "thefederal.com": "India",
    "edinburghlive.co.uk": "Scotland",
    "cnn.com": "United States",
    "northernirelandworld.com": "Northern Ireland",
    "japantimes.co.jp": "Japan",
    "gazettelive.co.uk": "England",
    "cbc.ca": "Canada",
    "thesun.my": "Malaysia",
    "newsday.com": "United States",
    "eurasiareview.com": "Global",
    "hurriyetdailynews.com": "Turkey",
    "thesouthafrican.com": "South Africa",
    "jewishpress.com": "United States",
    "abcactionnews.com": "United States",
    "nysun.com": "United States",
    "dw.com": "Germany",
    "huffingtonpost.co.uk": "England",
    "time.com": "United States",
    "standard.net.au": "Australia",
    "politico.eu": "Belgium",
    "dailypost.co.uk": "Wales",
    "northumberlandgazette.co.uk": "England",
    "cambridge-news.co.uk": "England",
    "kyivpost.com": "Ukraine",
    "npr.org": "United States",
    "theweek.com": "United States",
    "cnbc.com": "United States",
    "ntv.ca": "Canada",
    "the-independent.com": "United States",
    "africanews.com": "Republic of the Congo",  # Headquartered in Congo-Brazzaville
    "turan.az": "Azerbaijan",
    "chicagotribune.com": "United States",
    "palestinechronicle.com": "United States", # but about palestine
    "romania-insider.com": "Romania",
    "sfstandard.com": "United States",
    "themoscowtimes.com": "Russia", # They now operate out of amsterdan
    "syrianobserver.com": "International" # Often run by international or exiled groups form syria
}
newspaper_details= {
    "bnnbreaking.com": {
        "location": "Likely United States (or global online aggregator)",
        "political_side": "Varies (aggregated content)",
        "summary": "Online news aggregator focusing on breaking news headlines.",
        "popularity": "Less mainstream brand; predominantly online audience.",
        "known_facts": "Not to be confused with BNN Bloomberg; aims at quick ‘breaking’ updates."
    },
    "dailymail.co.uk": {
        "location": "United Kingdom",
        "political_side": "Right-leaning (conservative tabloid)",
        "summary": "A British tabloid known for sensational headlines and wide online reach (MailOnline).",
        "popularity": "Very popular online, one of the most visited English news sites globally.",
        "known_facts": "Founded in 1896; criticized for sensationalism, strong editorial stances."
    },
    "yahoo.com": {
        "location": "United States (global services)",
        "political_side": "Varies widely (aggregator for multiple sources)",
        "summary": "Major web portal offering email, search, and aggregated news content.",
        "popularity": "Historically one of the most visited websites globally.",
        "known_facts": "Founded in 1994; was once a dominant internet brand, still large in news aggregation."
    },
    "timesofindia.indiatimes.com": {
        "location": "India",
        "political_side": "Center to center-right (Times Group editorial line can vary)",
        "summary": "Largest English-language daily in India by circulation.",
        "popularity": "Extremely high readership, major presence online (Times Internet).",
        "known_facts": "Founded in 1838; part of The Times Group (Bennett, Coleman & Co.)."
    },
    "hindustantimes.com": {
        "location": "India",
        "political_side": "Generally center to slightly center-left",
        "summary": "Major English-language daily newspaper in India.",
        "popularity": "One of India’s top newspapers with large readership.",
        "known_facts": "Founded in 1924; HQ in Delhi, also significant presence in Mumbai."
    },
    "thehindu.com": {
        "location": "India",
        "political_side": "Center-left editorial stance",
        "summary": "One of India’s most respected English-language broadsheets.",
        "popularity": "High circulation nationally, especially in southern India.",
        "known_facts": "Founded in 1878; known for in-depth coverage, strong editorial standards."
    },
    "cbsnews.com": {
        "location": "United States",
        "political_side": "Center (traditional US network news approach)",
        "summary": "Major American TV network news division and digital platform.",
        "popularity": "One of the “Big Three” US broadcast networks.",
        "known_facts": "Produces ‘60 Minutes’ and other long-running news programs."
    },
    "forbes.com": {
        "location": "United States",
        "political_side": "Pro-business, typically center-right on economic matters",
        "summary": "Global media company focusing on business, investing, tech, and entrepreneurship.",
        "popularity": "Well-known for rich lists (Forbes 400) and extensive business journalism.",
        "known_facts": "Founded in 1917; famous for its “billionaires list” and entrepreneurial coverage."
    },
    "independent.co.uk": {
        "location": "United Kingdom",
        "political_side": "Center to center-left editorial stance",
        "summary": "British online newspaper (formerly a print paper) known as ‘The Indy.’",
        "popularity": "Well-known in the UK, with a growing international digital readership.",
        "known_facts": "Founded in 1986; went digital-only in 2016."
    },
    "ca.news.yahoo.com": {
        "location": "Canada",
        "political_side": "Varies (aggregator and wire service content)",
        "summary": "Yahoo’s Canada news portal, aggregating news from various sources.",
        "popularity": "Widely used as a news aggregator platform in Canada.",
        "known_facts": "Part of Yahoo’s global network; content from major Canadian outlets."
    },
    "dailystar.co.uk": {
        "location": "United Kingdom",
        "political_side": "Right-leaning tabloid style",
        "summary": "Tabloid newspaper known for celebrity gossip and sensational stories.",
        "popularity": "Popular for entertainment/tabloid coverage in the UK.",
        "known_facts": "Launched in 1978; sister paper is Daily Star Sunday."
    },
    "nzherald.co.nz": {
        "location": "New Zealand",
        "political_side": "Center-right editorial (largest newspaper in NZ)",
        "summary": "New Zealand’s biggest daily newspaper based in Auckland.",
        "popularity": "Dominant daily in NZ with a strong digital presence.",
        "known_facts": "Founded in 1863; owned by NZME."
    },
    "telegraph.co.uk": {
        "location": "United Kingdom",
        "political_side": "Right-leaning (conservative editorial line)",
        "summary": "The Daily Telegraph, a major national broadsheet in the UK.",
        "popularity": "High circulation, wide digital readership internationally.",
        "known_facts": "Founded in 1855; often referred to simply as ‘The Telegraph’."
    },
    "foxnews.com": {
        "location": "United States",
        "political_side": "Right-leaning (conservative)",
        "summary": "24-hour news channel and website with strong conservative commentary.",
        "popularity": "Very high in the U.S., consistently top cable news ratings.",
        "known_facts": "Launched in 1996 by Rupert Murdoch; known for influential prime-time hosts."
    },
    "bnnbloomberg.ca": {
        "location": "Canada",
        "political_side": "Business-focused, generally center",
        "summary": "Business news channel/website in partnership with Bloomberg.",
        "popularity": "Popular among Canadian business audiences.",
        "known_facts": "Formerly ‘Business News Network (BNN)’; rebranded after partnership with Bloomberg."
    },
    "thedailystar.net": {
        "location": "Bangladesh",
        "political_side": "Center-liberal editorial viewpoint",
        "summary": "Largest English-language daily in Bangladesh.",
        "popularity": "Highly influential among English-speaking population domestically and abroad.",
        "known_facts": "Founded in 1991; known for strong editorials and investigative reporting."
    },
    "globalnews.ca": {
        "location": "Canada",
        "political_side": "Generally center (mainstream Canadian broadcaster)",
        "summary": "National English-language TV news and online service from Corus Entertainment.",
        "popularity": "One of the major TV news providers in Canada, along with CTV and CBC.",
        "known_facts": "Operates local stations in various Canadian provinces."
    },
    "jpost.com": {
        "location": "Israel",
        "political_side": "Center-right or centrist from an Israeli perspective",
        "summary": "Jerusalem Post, a major English-language newspaper in Israel.",
        "popularity": "Highly read by English speakers interested in Israeli news.",
        "known_facts": "Founded in 1932 as The Palestine Post; global audience includes Jewish diaspora."
    },
    "theglobeandmail.com": {
        "location": "Canada",
        "political_side": "Center-right editorial stance (historically)",
        "summary": "National daily known for business and political reporting.",
        "popularity": "One of Canada’s most influential newspapers.",
        "known_facts": "Founded in 1844 (as The Globe); has won numerous awards."
    },
    "irishtimes.com": {
        "location": "Ireland",
        "political_side": "Center to liberal editorial line",
        "summary": "Leading Irish broadsheet newspaper covering national and international news.",
        "popularity": "Highly influential in Ireland’s political and cultural discourse.",
        "known_facts": "Founded in 1859; considered a ‘paper of record’ in Ireland."
    },
    "irishmirror.ie": {
        "location": "Ireland",
        "political_side": "Popular tabloid style (affiliated with the UK Mirror group, generally center-left)",
        "summary": "Irish version of the Daily Mirror, covering news, sports, and showbiz.",
        "popularity": "Well-read tabloid in Ireland.",
        "known_facts": "Focus on celebrity, sports, and local Irish news."
    },
    "pressandjournal.co.uk": {
        "location": "United Kingdom (Aberdeen, Scotland)",
        "political_side": "Local/regional coverage (historically leans conservative-liberal mix)",
        "summary": "One of Scotland’s oldest daily newspapers, covering north/northeast Scotland.",
        "popularity": "Regionally dominant in Aberdeenshire.",
        "known_facts": "Founded in 1747; often referred to as ‘the P&J’."
    },
    "tribuneindia.com": {
        "location": "India",
        "political_side": "Center to slightly center-left editorial stance",
        "summary": "The Tribune, English-language daily from North India.",
        "popularity": "Widely read in Punjab, Haryana, Himachal region.",
        "known_facts": "Established in 1881; known for regional coverage and editorial independence."
    },
    "inews.co.uk": {
        "location": "United Kingdom",
        "political_side": "Center to slightly center-left (balanced coverage)",
        "summary": "Website of the ‘i’ newspaper, known for concise coverage.",
        "popularity": "Moderate but growing digital presence in the UK.",
        "known_facts": "Originally a sister publication of The Independent."
    },
    "indiatimes.com": {
        "location": "India",
        "political_side": "Varies (part of The Times Group, often center)",
        "summary": "Portal under The Times Group; covers lifestyle, social media trends, and news.",
        "popularity": "High digital readership; wide content coverage.",
        "known_facts": "Operated by Bennett, Coleman & Co., owners of The Times of India."
    },
    "thestatesman.com": {
        "location": "India",
        "political_side": "Center to center-left (traditional Indian broadsheet)",
        "summary": "One of India’s oldest English newspapers, with roots in West Bengal.",
        "popularity": "Historically influential, moderate circulation now.",
        "known_facts": "Founded in 1875; known for editorial independence and legacy."
    },
    "nottinghampost.com": {
        "location": "United Kingdom (Nottingham, England)",
        "political_side": "Local/regional coverage",
        "summary": "Newspaper/website covering Nottingham and surrounding areas.",
        "popularity": "Widely read locally for news, sports, culture.",
        "known_facts": "Also known historically as the Evening Post."
    },
    "abcnews.go.com": {
        "location": "United States",
        "political_side": "Center to slightly center-left",
        "summary": "ABC News is a major US television news network and digital outlet.",
        "popularity": "Widely consumed nationally, part of the “Big Three” US networks.",
        "known_facts": "Owned by Disney; produces ‘Good Morning America’, ‘World News Tonight’."
    },
    "india.com": {
        "location": "India",
        "political_side": "Generally mainstream/center (mix of lifestyle & news)",
        "summary": "Digital news portal covering entertainment, sports, general news.",
        "popularity": "Popular for general interest and entertainment stories in India.",
        "known_facts": "Joint venture between Zee Entertainment and Penske Media Corporation."
    },
    "israelnationalnews.com": {
        "location": "Israel",
        "political_side": "Right-leaning religious nationalist viewpoint",
        "summary": "English-language site of Arutz Sheva, focusing on Israeli/Jewish affairs.",
        "popularity": "Niche among religious and right-wing audiences in Israel and abroad.",
        "known_facts": "Associated with Religious Zionist movement; also offers radio broadcasts."
    },
    "toronto.citynews.ca": {
        "location": "Canada",
        "political_side": "Local coverage, typically center",
        "summary": "CityNews Toronto covering local GTA news, weather, community issues.",
        "popularity": "Popular among Toronto residents; recognized TV brand in Canada.",
        "known_facts": "Owned by Rogers Media; integrated broadcast and digital platform."
    },
    "bostonglobe.com": {
        "location": "United States (Boston, Massachusetts)",
        "political_side": "Generally center-left editorial stance",
        "summary": "Major regional newspaper in New England with national influence.",
        "popularity": "Highly influential in the Boston area; known nationally for investigative journalism.",
        "known_facts": "Founded in 1872; multiple Pulitzer Prizes."
    },
    "tass.com": {
        "location": "Russia (state news agency)",
        "political_side": "Pro-Russian government stance",
        "summary": "Major Russian news agency with broad coverage and official angles.",
        "popularity": "Russia’s oldest news agency; official statements often come from TASS.",
        "known_facts": "Founded in 1904; previously known as Telegraph Agency of the Soviet Union."
    },
    "pressherald.com": {
        "location": "United States (Portland, Maine)",
        "political_side": "Traditionally center-left editorial stance",
        "summary": "Portland Press Herald, a major daily in Maine.",
        "popularity": "Most widely read newspaper in Maine.",
        "known_facts": "Traces its roots to 1862; known for local reporting."
    },
    "timeslive.co.za": {
        "location": "South Africa",
        "political_side": "Varies, mainstream coverage under Arena Holdings",
        "summary": "Online portal for The Sunday Times and related publications in South Africa.",
        "popularity": "Among the most visited news sites in South Africa.",
        "known_facts": "Focuses on local news, politics, sports, and opinion."
    },
    "cyprus-mail.com": {
        "location": "Cyprus",
        "political_side": "Generally center (English-language daily)",
        "summary": "One of Cyprus’s longest-running English-language newspapers.",
        "popularity": "Primarily read by English-speaking locals and expats in Cyprus.",
        "known_facts": "Founded in 1945; covers local and international news."
    },
    "thestar.co.uk": {
        "location": "United Kingdom (Sheffield)",
        "political_side": "Local/regional coverage",
        "summary": "Regional newspaper covering Sheffield and South Yorkshire.",
        "popularity": "Highly read locally.",
        "known_facts": "Founded in 1887; sister paper to the Sheffield Telegraph."
    },
    "euronews.com": {
        "location": "France (Pan-European)",
        "political_side": "Generally tries to present multiple European perspectives (center)",
        "summary": "European multilingual news network covering European and global news.",
        "popularity": "Widely distributed across Europe in multiple languages.",
        "known_facts": "Launched in 1993; known for multicultural coverage."
    },
    "rt.com": {
        "location": "Russia (state-funded)",
        "political_side": "Pro-Russian government viewpoint",
        "summary": "TV network and online outlet providing news from a Russian perspective.",
        "popularity": "Global brand, especially known for English broadcasts; controversial in Western media.",
        "known_facts": "Formerly ‘Russia Today’; widely considered propaganda by many Western observers."
    },
    "aljazeera.com": {
        "location": "Qatar (international focus)",
        "political_side": "Varies by region; often seen as progressive on Middle East coverage",
        "summary": "Major international news network funded by the Qatari government.",
        "popularity": "Global reach, particularly known for in-depth Middle Eastern coverage.",
        "known_facts": "Launched in 1996; recognized for documentaries and investigative journalism."
    },
    "sputnikglobe.com": {
        "location": "Russia (state-affiliated)",
        "political_side": "Pro-Russian government perspective",
        "summary": "International news agency established by Rossiya Segodnya (Russian gov’t-owned).",
        "popularity": "Known internationally for Russian state viewpoint; widely labeled propaganda in the West.",
        "known_facts": "Launched in 2014 to replace RIA Novosti’s international arm."
    },
    "kyivindependent.com": {
        "location": "Ukraine",
        "political_side": "Pro-democracy, liberal viewpoint",
        "summary": "English-language independent outlet launched by former Kyiv Post journalists.",
        "popularity": "Gained prominence internationally during the Russia-Ukraine conflict.",
        "known_facts": "Founded in 2021; crowdfunded, focusing on Ukrainian politics and war coverage."
    },
    "azernews.az": {
        "location": "Azerbaijan",
        "political_side": "Typically pro-government or neutral from Western perspective",
        "summary": "English-language newspaper focusing on Azerbaijani and regional news.",
        "popularity": "Niche internationally, better known within Azerbaijan.",
        "known_facts": "One of the main English news sources from Azerbaijan."
    },
    "chicago.suntimes.com": {
        "location": "United States (Chicago, Illinois)",
        "political_side": "Generally considered center-left editorially",
        "summary": "Tabloid-style daily newspaper in Chicago.",
        "popularity": "Well-known regionally; second-largest paper in Chicago after the Tribune.",
        "known_facts": "Founded in 1948; known for tabloid format and local focus."
    },
    "nbcnews.com": {
        "location": "United States",
        "political_side": "Center to center-left mainstream broadcast stance",
        "summary": "News division of NBC, a major American broadcast network.",
        "popularity": "One of the largest TV news audiences in the U.S.",
        "known_facts": "Produces ‘Today,’ ‘Nightly News,’ ‘Meet the Press,’ among others."
    },
    "dailysabah.com": {
        "location": "Turkey",
        "political_side": "Pro-government / conservative leaning",
        "summary": "Turkish daily newspaper published in English, close to the ruling AK Party perspective.",
        "popularity": "Known internationally among those who follow Turkish politics.",
        "known_facts": "Launched in 2014; part of the Turkuvaz Media Group."
    },
    "heraldscotland.com": {
        "location": "United Kingdom (Scotland)",
        "political_side": "Historically liberal/centrist",
        "summary": "The Herald is a Scottish broadsheet covering national and international news.",
        "popularity": "One of Scotland’s major newspapers.",
        "known_facts": "Founded in 1783; among the oldest newspapers in the world."
    },
    "huffpost.com": {
        "location": "United States (global editions)",
        "political_side": "Left-leaning overall",
        "summary": "American online news aggregator and blog founded by Arianna Huffington.",
        "popularity": "High in the U.S. digital media space.",
        "known_facts": "Won a Pulitzer Prize in 2012; one of the first digital-only outlets to gain mainstream acceptance."
    },
    "japannews.yomiuri.co.jp": {
        "location": "Japan",
        "political_side": "Generally considered conservative-leaning (Yomiuri Shimbun group)",
        "summary": "English-language version of Yomiuri Shimbun, a major Japanese newspaper.",
        "popularity": "Yomiuri is the highest-circulation newspaper in Japan (in Japanese).",
        "known_facts": "One of Japan’s oldest and most influential newspapers."
    },
    "thefederal.com": {
        "location": "India",
        "political_side": "Generally center to center-left",
        "summary": "Digital news platform focusing on Indian politics, economy, and society.",
        "popularity": "Smaller, newer digital outlet but growing audience.",
        "known_facts": "Offers explanatory journalism and analysis on Indian current affairs."
    },
    "edinburghlive.co.uk": {
        "location": "United Kingdom (Edinburgh, Scotland)",
        "political_side": "Local/regional coverage",
        "summary": "Digital news outlet covering Edinburgh and surrounding areas.",
        "popularity": "Locally popular for community news, events, local politics.",
        "known_facts": "Likely part of the Reach PLC group or similar local media."
    },
    "cnn.com": {
        "location": "United States",
        "political_side": "Center-left to center (often described as leaning left in US context)",
        "summary": "24-hour cable news channel and website, pioneering round-the-clock news coverage.",
        "popularity": "Internationally recognized with large global viewership.",
        "known_facts": "Founded by Ted Turner in 1980; known for major breaking news coverage."
    },
    "northernirelandworld.com": {
        "location": "Northern Ireland (UK)",
        "political_side": "Local/regional coverage (varied political environment)",
        "summary": "Covers regional news, politics, and community updates in Northern Ireland.",
        "popularity": "Locally recognized for community-level journalism.",
        "known_facts": "Likely part of JPIMedia or a similar local news group."
    },
    "japantimes.co.jp": {
        "location": "Japan",
        "political_side": "Historically liberal-leaning (English-language perspective)",
        "summary": "Oldest English-language newspaper in Japan, covering local and global news.",
        "popularity": "Widely read by English-speaking expatriates and international readers in Japan.",
        "known_facts": "Founded in 1897; focuses on Japanese politics, culture for English readers."
    },
    "gazettelive.co.uk": {
        "location": "United Kingdom (Teesside, England)",
        "political_side": "Local/regional coverage",
        "summary": "Online news for Teesside region, affiliated with The Gazette newspaper.",
        "popularity": "Locally significant in Northeast England.",
        "known_facts": "Focuses on local crime, community, sports, and events."
    },
    "cbc.ca": {
        "location": "Canada",
        "political_side": "Generally perceived as center-left (public broadcaster)",
        "summary": "Canada’s national public broadcaster, offering TV, radio, and online news.",
        "popularity": "Very high in Canada, widely trusted public media outlet.",
        "known_facts": "Federally funded; oldest existing broadcasting network in Canada."
    },
    "thesun.my": {
        "location": "Malaysia",
        "political_side": "Generally pro-government or center (Malaysia’s media environment varies)",
        "summary": "Free daily newspaper in Malaysia, widely distributed in urban areas.",
        "popularity": "Significant readership as a free paper.",
        "known_facts": "Operated by Sun Media; focuses on local/national news."
    },
    "newsday.com": {
        "location": "United States (Long Island, New York)",
        "political_side": "Moderate/centrist editorial viewpoint historically",
        "summary": "Daily newspaper primarily covering Long Island and the NYC region.",
        "popularity": "Widely read in Long Island; historically among top US papers by circulation.",
        "known_facts": "Founded in 1940; multiple Pulitzer Prizes for local reporting."
    },
    "eurasiareview.com": {
        "location": "Global (Online publication)",
        "political_side": "Varies (broad coverage on Eurasia/global issues)",
        "summary": "Independent journal focusing on geopolitical, social, and economic analysis.",
        "popularity": "Niche among policy analysts and those interested in Eurasian affairs.",
        "known_facts": "Publishes commentary and analysis from various authors/think-tanks."
    },
    "hurriyetdailynews.com": {
        "location": "Turkey",
        "political_side": "Historically more secular, can vary with ownership changes",
        "summary": "English-language Turkish newspaper covering national and regional news.",
        "popularity": "One of Turkey’s oldest English dailies, read by expats/diplomats.",
        "known_facts": "Part of Hürriyet group; editorial stance shifts with Turkey’s media climate."
    },
    "thesouthafrican.com": {
        "location": "South Africa",
        "political_side": "Generally neutral but focuses on SA diaspora news",
        "summary": "Online portal covering South African news, sports, culture, aimed also at expats.",
        "popularity": "Popular among South Africans abroad and at home for updates.",
        "known_facts": "Launched in 2003 in London; now also operating in South Africa."
    },
    "jewishpress.com": {
        "location": "United States (New York)",
        "political_side": "Right-leaning Orthodox Jewish perspective",
        "summary": "Weekly Jewish newspaper/online site focusing on religious and Israel-related news.",
        "popularity": "Niche among Orthodox and conservative Jewish communities.",
        "known_facts": "Founded in 1960; covers Jewish world news and religious commentary."
    },
    "abcactionnews.com": {
        "location": "United States (Tampa, Florida)",
        "political_side": "Generally center (local ABC affiliate)",
        "summary": "Local affiliate of ABC network covering Tampa Bay news.",
        "popularity": "Regionally popular in the Tampa Bay area.",
        "known_facts": "Part of the E. W. Scripps Company; focuses on local news, weather, consumer issues."
    },
    "nysun.com": {
        "location": "United States (New York)",
        "political_side": "Historically conservative or libertarian-leaning editorial page",
        "summary": "Online revival of the former daily The New York Sun.",
        "popularity": "More niche than mainstream, known for editorial commentary.",
        "known_facts": "Active in various forms since 2002; emphasizes political/cultural commentary."
    },
    "dw.com": {
        "location": "Germany",
        "political_side": "Generally center, public broadcaster perspective",
        "summary": "Deutsche Welle is Germany’s international broadcaster with global coverage.",
        "popularity": "Well-regarded internationally for factual news and cultural programs.",
        "known_facts": "Funded by the German government; provides content in 30+ languages."
    },
    "huffingtonpost.co.uk": {
        "location": "United Kingdom",
        "political_side": "Generally left-liberal commentary (UK edition)",
        "summary": "UK edition of HuffPost, focusing on British news, politics, entertainment.",
        "popularity": "Notable online presence in the UK.",
        "known_facts": "Owned by BuzzFeed (previously Verizon Media); known for blogging platform origins."
    },
    "time.com": {
        "location": "United States",
        "political_side": "Center-liberal mainstream magazine",
        "summary": "Long-running weekly news magazine covering global events, politics, culture.",
        "popularity": "Internationally recognized brand.",
        "known_facts": "Founded in 1923; famous for ‘Time Person of the Year’ cover."
    },
    "standard.net.au": {
        "location": "Australia",
        "political_side": "Local/regional (part of Australian community press)",
        "summary": "Likely The Warrnambool Standard or a regional ‘Standard’ publication in Australia.",
        "popularity": "Regional coverage focusing on local events, sports, and issues.",
        "known_facts": "Serves local Australian communities."
    },
    "politico.eu": {
        "location": "Belgium (European edition of Politico)",
        "political_side": "Center to center-left (policy-focused coverage)",
        "summary": "Focuses on EU institutions, European politics, and policy news.",
        "popularity": "Influential among European policymakers, journalists, and lobbyists.",
        "known_facts": "Launched as part of Politico’s expansion beyond the U.S."
    },
    "dailypost.co.uk": {
        "location": "United Kingdom (Wales)",
        "political_side": "Local/regional coverage",
        "summary": "Daily newspaper covering the North Wales region.",
        "popularity": "Popular locally in North Wales.",
        "known_facts": "Focus on local community issues, events, and sports."
    },
    "northumberlandgazette.co.uk": {
        "location": "United Kingdom (Northumberland, England)",
        "political_side": "Local/regional coverage",
        "summary": "Local paper focusing on Northumberland area news and events.",
        "popularity": "Popular in its coverage area.",
        "known_facts": "Long history of rural and community reporting."
    },
    "cambridge-news.co.uk": {
        "location": "United Kingdom (Cambridge)",
        "political_side": "Local/regional coverage (no strong national affiliation)",
        "summary": "Local newspaper/website covering the Cambridge region.",
        "popularity": "Locally popular for community and regional updates.",
        "known_facts": "Established in 1888; focuses on local politics, events, and schools."
    },
    "kyivpost.com": {
        "location": "Ukraine",
        "political_side": "Generally pro-Western, independent-liberal stance",
        "summary": "Ukraine’s oldest English-language newspaper, covering national/global news.",
        "popularity": "Key resource for English-language reporting on Ukraine.",
        "known_facts": "Founded in 1995; known for editorial independence coverage of Ukrainian politics."
    },
    "npr.org": {
        "location": "United States",
        "political_side": "Center-left public media perspective",
        "summary": "National Public Radio: non-profit media organization with news/cultural programs.",
        "popularity": "High among U.S. public radio audiences; respected for in-depth reporting.",
        "known_facts": "Publicly funded, with member stations across the US."
    },
    "theweek.com": {
        "location": "United States",
        "political_side": "Generally center (aggregates perspectives from left and right)",
        "summary": "Weekly news magazine that curates and summarizes stories from multiple angles.",
        "popularity": "Fairly popular for condensed news analysis/opinion.",
        "known_facts": "Started in the UK (1995), then US edition (2001); known for bridging differing viewpoints."
    },
    "cnbc.com": {
        "location": "United States",
        "political_side": "Business-focused, generally center",
        "summary": "24-hour business news channel/website under NBCUniversal.",
        "popularity": "Popular among business viewers and stock market followers.",
        "known_facts": "Launched in 1989; focuses on real-time financial market coverage."
    },
    "ntv.ca": {
        "location": "Canada (Newfoundland)",
        "political_side": "Local/regional coverage (private station)",
        "summary": "Canada’s oldest privately owned TV station, focusing on Newfoundland news.",
        "popularity": "Dominant in Newfoundland; lesser-known outside the province.",
        "known_facts": "Launched in 1955; strong local presence in Atlantic Canada."
    },
    "the-independent.com": {
        "location": "United States (Grand Island, Nebraska)",
        "political_side": "Local/regional coverage (no strong national affiliation)",
        "summary": "Grand Island Independent, a local daily in Nebraska.",
        "popularity": "Locally well-known; not widely known nationwide.",
        "known_facts": "Focuses on local reporting for central Nebraska communities."
    },
    "africanews.com": {
        "location": "Pan-African (headquartered in Congo-Brazzaville)",
        "political_side": "Varies (factual/news-oriented, affiliated with Euronews)",
        "summary": "Pan-African multilingual news outlet covering African and world news.",
        "popularity": "Gaining traction across African nations and internationally.",
        "known_facts": "Launched by Euronews in 2016; offers coverage in English and French."
    },
    "turan.az": {
        "location": "Azerbaijan",
        "political_side": "Independent stance, sometimes critical of government",
        "summary": "News agency providing local/regional coverage in Azerbaijan.",
        "popularity": "Niche but recognized as one of few independent sources in Azerbaijan.",
        "known_facts": "Has faced governmental pressure for investigative reporting."
    },
    "chicagotribune.com": {
        "location": "United States (Chicago, Illinois)",
        "political_side": "Historically center-right editorial page, though varied",
        "summary": "One of the largest newspapers in the Midwest, founded mid-19th century.",
        "popularity": "Highly influential in Illinois and the broader Midwest.",
        "known_facts": "Owned by Tribune Publishing; known for political endorsements/investigations."
    },
    "palestinechronicle.com": {
        "location": "Focus on Palestine (editorial offices often in North America)",
        "political_side": "Pro-Palestinian perspective, progressive-left stance",
        "summary": "Online publication focusing on Palestinian affairs, Middle East commentary.",
        "popularity": "Niche among readers interested in Middle East conflict/advocacy.",
        "known_facts": "Founded by Palestinian author Ramzy Baroud; features opinion pieces."
    },
    "romania-insider.com": {
        "location": "Romania",
        "political_side": "Generally neutral/center for English-speaking expats and business community",
        "summary": "Online portal covering Romanian news in English.",
        "popularity": "Popular among foreigners, investors, and diaspora seeking English news on Romania.",
        "known_facts": "Focuses on business, economic, and cultural updates in Romania."
    },
    "sfstandard.com": {
        "location": "United States (San Francisco, California)",
        "political_side": "Local/regional coverage in a generally progressive city",
        "summary": "Online outlet covering local SF news, culture, and politics.",
        "popularity": "Known regionally in the Bay Area’s digital news sphere.",
        "known_facts": "Founded relatively recently as a digital-first news platform."
    },
    "themoscowtimes.com": {
        "location": "Russia/Europe (historically Russia-based)",
        "political_side": "Independent, often critical of Russian government",
        "summary": "English-language newspaper covering Russian affairs.",
        "popularity": "Relied upon by expats and international audiences for Russia news in English.",
        "known_facts": "Founded in 1992; relocated much editorial work outside Russia due to restrictions."
    },
    "syrianobserver.com": {
        "location": "Focus on Syria (often run internationally or by exiled groups)",
        "political_side": "Opposition-friendly or independent perspective",
        "summary": "Daily news site translating and aggregating Syrian press, focusing on politics and civil society.",
        "popularity": "Specialized readership for Syrian conflict and Middle East watchers.",
        "known_facts": "Provides English translations of local Syrian publications with commentary on conflict."
    }
    # Skipping "None" entry.
}

# %% [markdown]
# ### Create a new csv that has one row for each newspaper

# %%
import polars as pl
import os
import csv

# Path to the output CSV file and header definition
output_file = "newspapers2024.csv"
header = [
    "Publisher",
    "Year",
    "Political Alignment",
    "Articles",
    "Article Count",
    "Corpus",
    "Corpus Word Count",
    "Unique Word Count"
]

# Determine if we need to write the header (i.e. file doesn't exist yet)
write_header = not os.path.exists(output_file)

# Open the output file in append mode
with open(output_file, "a", newline="", encoding="utf-8") as csvfile:
    writer = csv.writer(csvfile)

    # Write header if file is new
    if write_header:
        writer.writerow(header)

    # Iterate over each publisher in the list
    for publisher in publishers:
        # Lazily scan the CSV and filter for the specific publisher, selecting only the 'plain_text' column
        df_lazy = pl.scan_csv("2024.csv").filter(pl.col("publisher") == publisher).select("plain_text")
        filtered_df = df_lazy.collect()  # Materialize the filtered data

        # Initialize the articles list by extracting plain_text values
        articles = filtered_df["plain_text"].to_list()
        article_count = len(articles)

        # Set constant values
        year = 2024
        political_alignment = None
        corpus = None
        corpus_word_count = None
        unique_word_count = None

        # Append the new row to the CSV file
        writer.writerow([
            publisher,
            year,
            political_alignment,
            pl.lit(articles),
            article_count,
            corpus,
            corpus_word_count,
            unique_word_count
        ])
        print(f"Data for '{publisher}' appended successfully.")
        break
# Out:
# Data for 'abcactionnews.com' appended successfully.
# Data for 'abcnews.go.com' appended successfully.
# Data for 'africanews.com' appended successfully.
# Data for 'aljazeera.com' appended successfully.
# Data for 'azernews.az' appended successfully.
# Data for 'bnnbloomberg.ca' appended successfully.
# Data for 'bnnbreaking.com' appended successfully.
# Data for 'bostonglobe.com' appended successfully.
# Data for 'ca.news.yahoo.com' appended successfully.
# Data for 'cambridge-news.co.uk' appended successfully.
# Data for 'cbc.ca' appended successfully.
# Data for 'cbsnews.com' appended successfully.
# Data for 'chicago.suntimes.com' appended successfully.
# Data for 'chicagotribune.com' appended successfully.
# Data for 'cnbc.com' appended successfully.
# Data for 'cnn.com' appended successfully.
# Data for 'cyprus-mail.com' appended successfully.
# Data for 'dailymail.co.uk' appended successfully.
# Data for 'dailypost.co.uk' appended successfully.
# Data for 'dailysabah.com' appended successfully.
# Data for 'dailystar.co.uk' appended successfully.
# Data for 'dw.com' appended successfully.
# Data for 'edinburghlive.co.uk' appended successfully.
# Data for 'eurasiareview.com' appended successfully.
# Data for 'euronews.com' appended successfully.
# Data for 'forbes.com' appended successfully.
# Data for 'foxnews.com' appended successfully.
# Data for 'gazettelive.co.uk' appended successfully.
# Data for 'heraldscotland.com' appended successfully.
# Data for 'hindustantimes.com' appended successfully.
# Data for 'huffingtonpost.co.uk' appended successfully.
# Data for 'huffpost.com' appended successfully.
# Data for 'hurriyetdailynews.com' appended successfully.
# Data for 'independent.co.uk' appended successfully.
# Data for 'india.com' appended successfully.
# Data for 'indiatimes.com' appended successfully.
# Data for 'inews.co.uk' appended successfully.
# Data for 'irishmirror.ie' appended successfully.
# Data for 'irishtimes.com' appended successfully.
# Data for 'israelnationalnews.com' appended successfully.
# Data for 'japannews.yomiuri.co.jp' appended successfully.
# Data for 'japantimes.co.jp' appended successfully.
# Data for 'jewishpress.com' appended successfully.
# Data for 'jpost.com' appended successfully.
# Data for 'kyivindependent.com' appended successfully.
# Data for 'kyivpost.com' appended successfully.
# Data for 'nbcnews.com' appended successfully.
# Data for 'newsday.com' appended successfully.
# Data for 'northernirelandworld.com' appended successfully.
# Data for 'northumberlandgazette.co.uk' appended successfully.
# Data for 'nottinghampost.com' appended successfully.
# Data for 'npr.org' appended successfully.
# Data for 'ntv.ca' appended successfully.
# Data for 'nysun.com' appended successfully.
# Data for 'nzherald.co.nz' appended successfully.
# Data for 'palestinechronicle.com' appended successfully.
# Data for 'politico.eu' appended successfully.
# Data for 'pressandjournal.co.uk' appended successfully.
# Data for 'pressherald.com' appended successfully.
# Data for 'romania-insider.com' appended successfully.
# Data for 'sfstandard.com' appended successfully.
# Data for 'sputnikglobe.com' appended successfully.
# Data for 'standard.net.au' appended successfully.
# Data for 'telegraph.co.uk' appended successfully.
# Data for 'the-independent.com' appended successfully.
# Data for 'thedailystar.net' appended successfully.
# Data for 'thefederal.com' appended successfully.
# Data for 'theglobeandmail.com' appended successfully.
# Data for 'thehindu.com' appended successfully.
# Data for 'thesouthafrican.com' appended successfully.
# Data for 'thestar.co.uk' appended successfully.
# Data for 'thestatesman.com' appended successfully.
# Data for 'thesun.my' appended successfully.
# Data for 'theweek.com' appended successfully.
# Data for 'time.com' appended successfully.
# Data for 'timeslive.co.za' appended successfully.
# Data for 'timesofindia.indiatimes.com' appended successfully.
# Data for 'toronto.citynews.ca' appended successfully.
# Data for 'tribuneindia.com' appended successfully.
# Data for 'turan.az' appended successfully.
# Data for 'yahoo.com' appended successfully.
# Data for 'themoscowtimes.com' appended successfully.
# Data for 'globalnews.ca' appended successfully.
# Data for 'syrianobserver.com' appended successfully.
# Data for 'tass.com' appended successfully.
# Data for 'rt.com' appended successfully.

# %% [markdown]
# ### Read the CSV file and display the first few rows

# %%
import polars as pl
# Lazy scan the CSV file
df_lazy = pl.scan_csv("newspapers2024.csv")
sample_df = df_lazy.head(5).collect() # only first 5 rows
print(sample_df)
# Out:
# shape: (5, 8)
# ┌──────────────┬──────┬──────────────┬──────────────┬─────────┬────────┬─────────────┬─────────────┐
# │ Publisher    ┆ Year ┆ Political    ┆ Articles     ┆ Article ┆ Corpus ┆ Corpus Word ┆ Unique Word │
# │ ---          ┆ ---  ┆ Alignment    ┆ ---          ┆ Count   ┆ ---    ┆ Count       ┆ Count       │
# │ str          ┆ i64  ┆ ---          ┆ str          ┆ ---     ┆ str    ┆ ---         ┆ ---         │
# │              ┆      ┆ str          ┆              ┆ i64     ┆        ┆ str         ┆ str         │
# ╞══════════════╪══════╪══════════════╪══════════════╪═════════╪════════╪═════════════╪═════════════╡
# │ abcactionnew ┆ 2024 ┆ null         ┆ ['TAMPA,     ┆ 3312    ┆ null   ┆ null        ┆ null        │
# │ s.com        ┆      ┆              ┆ Fla. — Lyme  ┆         ┆        ┆             ┆             │
# │              ┆      ┆              ┆ disease i…   ┆         ┆        ┆             ┆             │
# │ abcnews.go.c ┆ 2024 ┆ null         ┆ ['Last round ┆ 8643    ┆ null   ┆ null        ┆ null        │
# │ om           ┆      ┆              ┆ of voting    ┆         ┆        ┆             ┆             │
# │              ┆      ┆              ┆ begins …     ┆         ┆        ┆             ┆             │
# │ africanews.c ┆ 2024 ┆ null         ┆ ["Morocco    ┆ 1899    ┆ null   ┆ null        ┆ null        │
# │ om           ┆      ┆              ┆ organized    ┆         ┆        ┆             ┆             │
# │              ┆      ┆              ┆ its first …  ┆         ┆        ┆             ┆             │
# │ aljazeera.co ┆ 2024 ┆ null         ┆ ['As a       ┆ 6384    ┆ null   ┆ null        ┆ null        │
# │ m            ┆      ┆              ┆ 20-week-old  ┆         ┆        ┆             ┆             │
# │              ┆      ┆              ┆ embryo, Cho… ┆         ┆        ┆             ┆             │
# │ azernews.az  ┆ 2024 ┆ null         ┆ ['Baku and   ┆ 5730    ┆ null   ┆ null        ┆ null        │
# │              ┆      ┆              ┆ Astana hold  ┆         ┆        ┆             ┆             │
# │              ┆      ┆              ┆ talks o…     ┆         ┆        ┆             ┆             │
# └──────────────┴──────┴──────────────┴──────────────┴─────────┴────────┴─────────────┴─────────────┘
